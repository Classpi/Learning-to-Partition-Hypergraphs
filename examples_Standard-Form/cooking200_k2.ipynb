# %%
import sys
sys.path.append("../")

# %%
import torch
import torch.optim as optim
from torch import nn

import hgp
from hgp.models import HGNNP,CHGNN
from hgp.function import StraightThroughEstimator

import numpy as np
import random
DEVICE = torch.device("cuda:0") if torch.cuda.is_available() else torch.device("cpu")
DEVICE
# Out:
# device(type='cuda', index=0)

# %%
seed = 42
torch.manual_seed(seed) 
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  
np.random.seed(seed)  
random.seed(seed)  
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %%
from hgp.models import ParameterDict

# fmt: off
h_hyper_prmts = ParameterDict()
l_hyper_prmts = ParameterDict()

partitions = 2

weight = 220000
limit = 20
sub = 20
lr = 4e-5

h_hyper_prmts["convlayers1"] = {"in_channels": 7000, "out_channels": 1024, "use_bn": False, "drop_rate": 0.9}
h_hyper_prmts["convlayers1"] = {"in_channels": 1024, "out_channels": 1024, "use_bn": False, "drop_rate": 0}
h_hyper_prmts["convlayers12"] = {"in_channels": 1024, "out_channels": 512, "use_bn": False, "drop_rate": 0}
h_hyper_prmts["convlayers14"] = {"in_channels": 512, "out_channels": 256, "use_bn": False, "drop_rate": 0}
# h_hyper_prmts["convlayers13"] = {"in_channels": 256, "out_channels": 128, "use_bn": False, "drop_rate": 0}
# h_hyper_prmts["convlayers131"] = {"in_channels": 128, "out_channels": 64, "use_bn": False, "drop_rate": 0}


l_hyper_prmts["linerlayer1"] = {"in_channels":list(h_hyper_prmts.values())[-1]["out_channels"], "out_channels":64, "use_bn":False, "drop_rate":0.05}
# l_hyper_prmts["linerlayer42"] = {"in_channels":64, "out_channels":32, "use_bn":False, "drop_rate":0.05}
# l_hyper_prmts["linerlayer421"] = {"in_channels":32, "out_channels":16, "use_bn":False, "drop_rate":0.05}
# l_hyper_prmts["linerlayer422"] = {"in_channels":16, "out_channels":8, "use_bn":False, "drop_rate":0.05}
l_hyper_prmts["linerlayer423"] = {"in_channels":64, "out_channels":2, "use_bn":True, "drop_rate":0.05}


hyper = {
    "h_hyper_prmts": h_hyper_prmts,
    "l_hyper_prmts":l_hyper_prmts,
    "init_features_dim":list(h_hyper_prmts.values())[0]["in_channels"],
    "partitions":partitions
}

# fmt: on

# %%
def loss_bs_matrix(outs, hg, device, weight):

    H = hg.H.to_dense().to(device)
    outs = outs.to(device)

    X_ = outs.t().unsqueeze(-1)
    H_ = H.unsqueeze(0)
    xweight = H.sum(dim=0)
    mid = X_.mul(H_)
    sum = (mid * (1 / xweight)).sum()
    sub = (mid + (1 - H)).prod(dim=1).sum()
    loss_1 = sum - sub

    loss_2 = torch.var(torch.sum(outs, dim=0)).to(device)
    loss = weight * loss_1 + loss_2

    return loss, loss_1, loss_2

# %%
class Trainer(nn.Module):

    def __init__(self, net, X, hg, optimizer):
        super().__init__()
        self.X: torch.Tensor = X.to(DEVICE)
        self.hg = hg.to(DEVICE)
        self.de = self.hg.H.to_dense().sum(dim=0).to("cpu").to(DEVICE)
        self.optimizer: torch.optim.Optimizer = optimizer
        self.layers = nn.ModuleList()
        self.layers.append(net.to(DEVICE))
        self.weight = 200
    def forward(self, X):
        X = self.layers[0](X, self.hg)
        for layer in self.layers[1:]:
            X = layer(X)
        return X

    def run(self, epoch):
        self.train()  
        self.optimizer.zero_grad()
        outs = self.forward(self.X)
        loss, loss_1, loss_2 = loss_bs_matrix(outs, self.hg, device=DEVICE,weight=self.weight)
        loss.backward()
        self.optimizer.step()

        return loss.item(), loss_1.item(), loss_2.item()

# %%
import dhg 
from dhg.data import Cooking200
data = Cooking200()
e_list = data["edge_list"]
num_v = data["num_vertices"]
G = dhg.Hypergraph(data["num_vertices"],data["edge_list"])
num_v, data["num_edges"]
# Out:
# (7403, 2755)

# %%
X = torch.randn(size=(G.num_v, hyper["init_features_dim"]))
# X = torch.eye(hyper["init_features_dim"])
net = HGNNP(hyper["h_hyper_prmts"]).to(DEVICE)
hgnn_trainer = Trainer(net=net, X=X, hg=G, optimizer=None).to(DEVICE)
for (k,v) in hyper["l_hyper_prmts"].items():
    hgnn_trainer.layers.append(nn.BatchNorm1d(num_features=v["in_channels"]).to(DEVICE)) if v["use_bn"] else None
    hgnn_trainer.layers.append(nn.ReLU6().to(DEVICE))
    if v["drop_rate"] > 0:
        hgnn_trainer.layers.append(nn.Dropout(v["drop_rate"]))
    hgnn_trainer.layers.append(nn.Linear(in_features=v["in_channels"],out_features=v["out_channels"],device=DEVICE))
hgnn_trainer.layers.append(nn.Softmax(dim=1))
# Out:
# ModuleList(
#   (0): HGNNP(
#     (layers): ModuleList(
#       (0): HGNNPConv(
#         (act): ReLU(inplace=True)
#         (drop): Dropout(p=0, inplace=False)
#         (theta): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#       (1): HGNNPConv(
#         (act): ReLU(inplace=True)
#         (drop): Dropout(p=0, inplace=False)
#         (theta): Linear(in_features=1024, out_features=512, bias=True)
#       )
#       (2): HGNNPConv(
#         (act): ReLU(inplace=True)
#         (drop): Dropout(p=0, inplace=False)
#         (theta): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#   )
#   (1): ReLU6()
#   (2): Dropout(p=0.05, inplace=False)
#   (3): Linear(in_features=256, out_features=64, bias=True)
#   (4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU6()
#   (6): Dropout(p=0.05, inplace=False)
#   (7): Linear(in_features=64, out_features=2, bias=True)
#   (8): Softmax(dim=1)
# )

# %%
# hgnn_trainer.layers
# for n,p in hgnn_trainer.named_parameters():
#     print(n,p)
hgnn_trainer.weight = weight

# %%
temp_loss_total, temp_loss1, temp_loss2 = torch.zeros(1, requires_grad=False), torch.zeros(1, requires_grad=False), torch.zeros(1, requires_grad=False)
optim1 = optim.Adam(hgnn_trainer.parameters(), lr=lr, weight_decay=5e-8)
hgnn_trainer.optimizer = optim1
for epoch in range(40000):
    if hgnn_trainer.weight >= 64000:
        hgnn_trainer.weight = hgnn_trainer.weight - sub
    elif hgnn_trainer.weight < 64000 and hgnn_trainer.weight > limit:
        hgnn_trainer.weight = hgnn_trainer.weight - (sub / 2)
    elif hgnn_trainer.weight < limit:
        hgnn_trainer.weight = limit
    loss, loss_1, loss_2 = hgnn_trainer.run(epoch=epoch)
    temp_loss_total += loss
    temp_loss1 += loss_1
    temp_loss2 += loss_2
    if epoch % 10 == 0:
        print(f"in {epoch} epoch, average loss: {temp_loss_total.item() / 10}")
        print(f"                , loss1: {temp_loss1.item() / 10}")
        print(f"                , loss2: {temp_loss2.item() / 10}")
        print(f"                , weight: {hgnn_trainer.weight}")
        print(f"=================================")
        sys.stdout.flush()
        temp_loss_total, temp_loss1, temp_loss2 = torch.zeros(1, requires_grad=False), torch.zeros(1, requires_grad=False), torch.zeros(1, requires_grad=False)
# Out:
# in 0 epoch, average loss: 51092393.6
#                 , loss1: 231.896533203125
#                 , loss2: 79794.59375
#                 , weight: 219980
# =================================
# in 10 epoch, average loss: 506831769.6
#                 , loss1: 2301.0470703125
#                 , loss2: 899934.8
#                 , weight: 219780
# =================================
# in 20 epoch, average loss: 496574924.8
#                 , loss1: 2255.9458984375
#                 , loss2: 1010314.1
#                 , weight: 219580
# =================================
# in 30 epoch, average loss: 482534297.6
#                 , loss1: 2194.28359375
#                 , loss2: 953884.4
#                 , weight: 219380
# =================================
# in 40 epoch, average loss: 466304102.4
#                 , loss1: 2122.5296875
#                 , loss2: 895771.5
#                 , weight: 219180
# =================================
# in 50 epoch, average loss: 447898982.4
#                 , loss1: 2039.77109375
#                 , loss2: 1044932.0
#                 , weight: 218980
# =================================
# in 60 epoch, average loss: 430939033.6
#                 , loss1: 1963.51015625
#                 , loss2: 1184472.1
#                 , weight: 218780
# =================================
# in 70 epoch, average loss: 417515264.0
#                 , loss1: 1903.58359375
#                 , loss2: 1257779.4
#                 , weight: 218580
# =================================
# in 80 epoch, average loss: 406935449.6
#                 , loss1: 1856.9591796875
#                 , loss2: 1244871.8
#                 , weight: 218380
# =================================
# in 90 epoch, average loss: 397887641.6
#                 , loss1: 1817.3990234375
#                 , loss2: 1203388.4
#                 , weight: 218180
# =================================
# in 100 epoch, average loss: 390160460.8
#                 , loss1: 1783.7556640625
#                 , loss2: 1176403.6
#                 , weight: 217980
# =================================
# in 110 epoch, average loss: 383665996.8
#                 , loss1: 1755.5162109375
#                 , loss2: 1191267.1
#                 , weight: 217780
# =================================
# in 120 epoch, average loss: 377897651.2
#                 , loss1: 1730.5328125
#                 , loss2: 1212188.0
#                 , weight: 217580
# =================================
# in 130 epoch, average loss: 372770150.4
#                 , loss1: 1708.3798828125
#                 , loss2: 1248422.6
#                 , weight: 217380
# =================================
# in 140 epoch, average loss: 368255385.6
#                 , loss1: 1688.9939453125
#                 , loss2: 1287382.9
#                 , weight: 217180
# =================================
# in 150 epoch, average loss: 364253414.4
#                 , loss1: 1671.925390625
#                 , loss2: 1328279.9
#                 , weight: 216980
# =================================
# in 160 epoch, average loss: 360326348.8
#                 , loss1: 1655.1513671875
#                 , loss2: 1373444.5
#                 , weight: 216780
# =================================
# in 170 epoch, average loss: 356696140.8
#                 , loss1: 1639.8205078125
#                 , loss2: 1396036.3
#                 , weight: 216580
# =================================
# in 180 epoch, average loss: 353397708.8
#                 , loss1: 1626.009375
#                 , loss2: 1415241.0
#                 , weight: 216380
# =================================
# in 190 epoch, average loss: 350150860.8
#                 , loss1: 1612.35546875
#                 , loss2: 1446523.6
#                 , weight: 216180
# =================================
# in 200 epoch, average loss: 347041510.4
#                 , loss1: 1599.39892578125
#                 , loss2: 1459180.6
#                 , weight: 215980
# =================================
# in 210 epoch, average loss: 343962035.2
#                 , loss1: 1586.5828125
#                 , loss2: 1466126.4
#                 , weight: 215780
# =================================
# in 220 epoch, average loss: 340914355.2
#                 , loss1: 1573.91337890625
#                 , loss2: 1468247.9
#                 , weight: 215580
# =================================
# in 230 epoch, average loss: 337805440.0
#                 , loss1: 1560.98369140625
#                 , loss2: 1460061.4
#                 , weight: 215380
# =================================
# in 240 epoch, average loss: 334722995.2
#                 , loss1: 1548.17685546875
#                 , loss2: 1446735.0
#                 , weight: 215180
# =================================
# in 250 epoch, average loss: 331705344.0
#                 , loss1: 1535.65751953125
#                 , loss2: 1431263.8
#                 , weight: 214980
# =================================
# in 260 epoch, average loss: 328690764.8
#                 , loss1: 1523.00537109375
#                 , loss2: 1442343.1
#                 , weight: 214780
# =================================
# in 270 epoch, average loss: 325571737.6
#                 , loss1: 1509.871875
#                 , loss2: 1447358.9
#                 , weight: 214580
# =================================
# in 280 epoch, average loss: 322583705.6
#                 , loss1: 1497.42119140625
#                 , loss2: 1431594.8
#                 , weight: 214380
# =================================
# in 290 epoch, average loss: 319656985.6
#                 , loss1: 1485.2001953125
#                 , loss2: 1422942.3
#                 , weight: 214180
# =================================
# in 300 epoch, average loss: 316806860.8
#                 , loss1: 1473.33232421875
#                 , loss2: 1410394.6
#                 , weight: 213980
# =================================
# in 310 epoch, average loss: 313865446.4
#                 , loss1: 1461.0189453125
#                 , loss2: 1397141.3
#                 , weight: 213780
# =================================
# in 320 epoch, average loss: 311260774.4
#                 , loss1: 1450.3142578125
#                 , loss2: 1371919.2
#                 , weight: 213580
# =================================
# in 330 epoch, average loss: 308559411.2
#                 , loss1: 1439.17197265625
#                 , loss2: 1339171.5
#                 , weight: 213380
# =================================
# in 340 epoch, average loss: 305923993.6
#                 , loss1: 1428.27578125
#                 , loss2: 1315498.5
#                 , weight: 213180
# =================================
# in 350 epoch, average loss: 303614182.4
#                 , loss1: 1418.65263671875
#                 , loss2: 1341707.4
#                 , weight: 212980
# =================================
# in 360 epoch, average loss: 301161753.6
#                 , loss1: 1408.61728515625
#                 , loss2: 1309192.5
#                 , weight: 212780
# =================================
# in 370 epoch, average loss: 298872627.2
#                 , loss1: 1399.251171875
#                 , loss2: 1293743.0
#                 , weight: 212580
# =================================
# in 380 epoch, average loss: 296577254.4
#                 , loss1: 1389.76953125
#                 , loss2: 1292787.2
#                 , weight: 212380
# =================================
# in 390 epoch, average loss: 294497280.0
#                 , loss1: 1381.36904296875
#                 , loss2: 1273948.6
#                 , weight: 212180
# =================================
# in 400 epoch, average loss: 292318873.6
#                 , loss1: 1372.41923828125
#                 , loss2: 1269831.1
#                 , weight: 211980
# =================================
# in 410 epoch, average loss: 290171776.0
#                 , loss1: 1363.66083984375
#                 , loss2: 1252865.9
#                 , weight: 211780
# =================================
# in 420 epoch, average loss: 288460723.2
#                 , loss1: 1356.82763671875
#                 , loss2: 1260881.1
#                 , weight: 211580
# =================================
# in 430 epoch, average loss: 286503014.4
#                 , loss1: 1348.9759765625
#                 , loss2: 1234955.7
#                 , weight: 211380
# =================================
# in 440 epoch, average loss: 284778547.2
#                 , loss1: 1342.1025390625
#                 , loss2: 1232441.8
#                 , weight: 211180
# =================================
# in 450 epoch, average loss: 283051212.8
#                 , loss1: 1335.19443359375
#                 , loss2: 1231598.1
#                 , weight: 210980
# =================================
# in 460 epoch, average loss: 281568588.8
#                 , loss1: 1329.36630859375
#                 , loss2: 1245009.0
#                 , weight: 210780
# =================================
# in 470 epoch, average loss: 279787264.0
#                 , loss1: 1322.2501953125
#                 , loss2: 1228721.8
#                 , weight: 210580
# =================================
# in 480 epoch, average loss: 278279987.2
#                 , loss1: 1316.36640625
#                 , loss2: 1224269.9
#                 , weight: 210380
# =================================
# in 490 epoch, average loss: 277006054.4
#                 , loss1: 1311.5986328125
#                 , loss2: 1216197.7
#                 , weight: 210180
# =================================
# in 500 epoch, average loss: 275696614.4
#                 , loss1: 1306.5890625
#                 , loss2: 1221377.0
#                 , weight: 209980
# =================================
# in 510 epoch, average loss: 274259584.0
#                 , loss1: 1301.1384765625
#                 , loss2: 1189583.9
#                 , weight: 209780
# =================================
# in 520 epoch, average loss: 272990924.8
#                 , loss1: 1296.31396484375
#                 , loss2: 1192687.0
#                 , weight: 209580
# =================================
# in 530 epoch, average loss: 271767424.0
#                 , loss1: 1291.7146484375
#                 , loss2: 1191855.3
#                 , weight: 209380
# =================================
# in 540 epoch, average loss: 270604620.8
#                 , loss1: 1287.4173828125
#                 , loss2: 1186709.0
#                 , weight: 209180
# =================================
# in 550 epoch, average loss: 269498675.2
#                 , loss1: 1283.357421875
#                 , loss2: 1187046.7
#                 , weight: 208980
# =================================
# in 560 epoch, average loss: 268397107.2
#                 , loss1: 1279.31513671875
#                 , loss2: 1186501.0
#                 , weight: 208780
# =================================
# in 570 epoch, average loss: 267333222.4
#                 , loss1: 1275.5017578125
#                 , loss2: 1174238.4
#                 , weight: 208580
# =================================
# in 580 epoch, average loss: 266224716.8
#                 , loss1: 1271.390625
#                 , loss2: 1177839.4
#                 , weight: 208380
# =================================
# in 590 epoch, average loss: 265216819.2
#                 , loss1: 1267.8298828125
#                 , loss2: 1165857.4
#                 , weight: 208180
# =================================
# in 600 epoch, average loss: 264285516.8
#                 , loss1: 1264.50517578125
#                 , loss2: 1179877.9
#                 , weight: 207980
# =================================
# in 610 epoch, average loss: 263221248.0
#                 , loss1: 1260.63916015625
#                 , loss2: 1172163.3
#                 , weight: 207780
# =================================
# in 620 epoch, average loss: 262234777.6
#                 , loss1: 1257.112109375
#                 , loss2: 1170242.6
#                 , weight: 207580
# =================================
# in 630 epoch, average loss: 261265740.8
#                 , loss1: 1253.67451171875
#                 , loss2: 1165857.5
#                 , weight: 207380
# =================================
# in 640 epoch, average loss: 260364492.8
#                 , loss1: 1250.5193359375
#                 , loss2: 1169297.5
#                 , weight: 207180
# =================================
# in 650 epoch, average loss: 259591091.2
#                 , loss1: 1248.066015625
#                 , loss2: 1153985.5
#                 , weight: 206980
# =================================
# in 660 epoch, average loss: 258725555.2
#                 , loss1: 1245.06552734375
#                 , loss2: 1158802.6
#                 , weight: 206780
# =================================
# in 670 epoch, average loss: 257779968.0
#                 , loss1: 1241.74658203125
#                 , loss2: 1148126.1
#                 , weight: 206580
# =================================
# in 680 epoch, average loss: 256991513.6
#                 , loss1: 1239.2013671875
#                 , loss2: 1133586.5
#                 , weight: 206380
# =================================
# in 690 epoch, average loss: 256174592.0
#                 , loss1: 1236.4423828125
#                 , loss2: 1133607.5
#                 , weight: 206180
# =================================
# in 700 epoch, average loss: 255453849.6
#                 , loss1: 1234.184765625
#                 , loss2: 1125357.6
#                 , weight: 205980
# =================================
# in 710 epoch, average loss: 254723353.6
#                 , loss1: 1231.87265625
#                 , loss2: 1117650.0
#                 , weight: 205780
# =================================
# in 720 epoch, average loss: 253934822.4
#                 , loss1: 1229.24853515625
#                 , loss2: 1115241.6
#                 , weight: 205580
# =================================
# in 730 epoch, average loss: 253310182.4
#                 , loss1: 1227.42236328125
#                 , loss2: 1111687.1
#                 , weight: 205380
# =================================
# in 740 epoch, average loss: 252598579.2
#                 , loss1: 1225.18232421875
#                 , loss2: 1105365.6
#                 , weight: 205180
# =================================
# in 750 epoch, average loss: 251985228.8
#                 , loss1: 1223.37109375
#                 , loss2: 1108486.9
#                 , weight: 204980
# =================================
# in 760 epoch, average loss: 251206528.0
#                 , loss1: 1220.84375
#                 , loss2: 1092235.9
#                 , weight: 204780
# =================================
# in 770 epoch, average loss: 250470886.4
#                 , loss1: 1218.4041015625
#                 , loss2: 1100064.0
#                 , weight: 204580
# =================================
# in 780 epoch, average loss: 249785523.2
#                 , loss1: 1216.2525390625
#                 , loss2: 1098303.3
#                 , weight: 204380
# =================================
# in 790 epoch, average loss: 249125299.2
#                 , loss1: 1214.24609375
#                 , loss2: 1091214.0
#                 , weight: 204180
# =================================
# in 800 epoch, average loss: 248478720.0
#                 , loss1: 1212.23505859375
#                 , loss2: 1097862.1
#                 , weight: 203980
# =================================
# in 810 epoch, average loss: 247894707.2
#                 , loss1: 1210.51748046875
#                 , loss2: 1106475.6
#                 , weight: 203780
# =================================
# in 820 epoch, average loss: 247291622.4
#                 , loss1: 1208.79306640625
#                 , loss2: 1096654.2
#                 , weight: 203580
# =================================
# in 830 epoch, average loss: 246444288.0
#                 , loss1: 1205.8138671875
#                 , loss2: 1097331.8
#                 , weight: 203380
# =================================
# in 840 epoch, average loss: 245801011.2
#                 , loss1: 1203.85322265625
#                 , loss2: 1093762.5
#                 , weight: 203180
# =================================
# in 850 epoch, average loss: 245111961.6
#                 , loss1: 1201.6400390625
#                 , loss2: 1094884.6
#                 , weight: 202980
# =================================
# in 860 epoch, average loss: 244501504.0
#                 , loss1: 1199.81787109375
#                 , loss2: 1094413.6
#                 , weight: 202780
# =================================
# in 870 epoch, average loss: 243864576.0
#                 , loss1: 1197.84951171875
#                 , loss2: 1096348.0
#                 , weight: 202580
# =================================
# in 880 epoch, average loss: 243279257.6
#                 , loss1: 1196.14228515625
#                 , loss2: 1096344.3
#                 , weight: 202380
# =================================
# in 890 epoch, average loss: 242755814.4
#                 , loss1: 1194.75390625
#                 , loss2: 1092904.7
#                 , weight: 202180
# =================================
# in 900 epoch, average loss: 242145740.8
#                 , loss1: 1192.96201171875
#                 , loss2: 1083872.6
#                 , weight: 201980
# =================================
# in 910 epoch, average loss: 241638272.0
#                 , loss1: 1191.68466796875
#                 , loss2: 1072892.1
#                 , weight: 201780
# =================================
# in 920 epoch, average loss: 241046912.0
#                 , loss1: 1189.88525390625
#                 , loss2: 1082728.5
#                 , weight: 201580
# =================================
# in 930 epoch, average loss: 240520806.4
#                 , loss1: 1188.527734375
#                 , loss2: 1068129.0
#                 , weight: 201380
# =================================
# in 940 epoch, average loss: 240008934.4
#                 , loss1: 1187.1994140625
#                 , loss2: 1061279.5
#                 , weight: 201180
# =================================
# in 950 epoch, average loss: 239532006.4
#                 , loss1: 1186.0421875
#                 , loss2: 1054495.2
#                 , weight: 200980
# =================================
# in 960 epoch, average loss: 239040358.4
#                 , loss1: 1184.7908203125
#                 , loss2: 1051430.6
#                 , weight: 200780
# =================================
# in 970 epoch, average loss: 238534041.6
#                 , loss1: 1183.39443359375
#                 , loss2: 1062266.5
#                 , weight: 200580
# =================================
# in 980 epoch, average loss: 238062848.0
#                 , loss1: 1182.2470703125
#                 , loss2: 1057725.8
#                 , weight: 200380
# =================================
# in 990 epoch, average loss: 237580288.0
#                 , loss1: 1181.03076171875
#                 , loss2: 1055236.1
#                 , weight: 200180
# =================================
# in 1000 epoch, average loss: 237078553.6
#                 , loss1: 1179.71201171875
#                 , loss2: 1053540.4
#                 , weight: 199980
# =================================
# in 1010 epoch, average loss: 236562636.8
#                 , loss1: 1178.269921875
#                 , loss2: 1061805.0
#                 , weight: 199780
# =================================
# in 1020 epoch, average loss: 236022246.4
#                 , loss1: 1176.7650390625
#                 , loss2: 1057528.4
#                 , weight: 199580
# =================================
# in 1030 epoch, average loss: 235483904.0
#                 , loss1: 1175.2162109375
#                 , loss2: 1063464.2
#                 , weight: 199380
# =================================
# in 1040 epoch, average loss: 234920524.8
#                 , loss1: 1173.6130859375
#                 , loss2: 1054613.1
#                 , weight: 199180
# =================================
# in 1050 epoch, average loss: 234332467.2
#                 , loss1: 1171.805859375
#                 , loss2: 1061038.7
#                 , weight: 198980
# =================================
# in 1060 epoch, average loss: 233972019.2
#                 , loss1: 1171.276171875
#                 , loss2: 1040302.7
#                 , weight: 198780
# =================================
# in 1070 epoch, average loss: 233406489.6
#                 , loss1: 1169.6494140625
#                 , loss2: 1032219.6
#                 , weight: 198580
# =================================
# in 1080 epoch, average loss: 232918528.0
#                 , loss1: 1168.4044921875
#                 , loss2: 1025288.7
#                 , weight: 198380
# =================================
# in 1090 epoch, average loss: 232475494.4
#                 , loss1: 1167.406640625
#                 , loss2: 1013781.3
#                 , weight: 198180
# =================================
# in 1100 epoch, average loss: 232081792.0
#                 , loss1: 1166.57646484375
#                 , loss2: 1017975.1
#                 , weight: 197980
# =================================
# in 1110 epoch, average loss: 231609011.2
#                 , loss1: 1165.3884765625
#                 , loss2: 1013559.7
#                 , weight: 197780
# =================================
# in 1120 epoch, average loss: 231137766.4
#                 , loss1: 1164.23310546875
#                 , loss2: 1003811.7
#                 , weight: 197580
# =================================
# in 1130 epoch, average loss: 230659302.4
#                 , loss1: 1162.98818359375
#                 , loss2: 1004003.6
#                 , weight: 197380
# =================================
# in 1140 epoch, average loss: 230231756.8
#                 , loss1: 1161.91611328125
#                 , loss2: 1020579.6
#                 , weight: 197180
# =================================
# in 1150 epoch, average loss: 229771264.0
#                 , loss1: 1160.81689453125
#                 , loss2: 1009059.4
#                 , weight: 196980
# =================================
# in 1160 epoch, average loss: 229349196.8
#                 , loss1: 1159.81982421875
#                 , loss2: 1015446.3
#                 , weight: 196780
# =================================
# in 1170 epoch, average loss: 228799104.0
#                 , loss1: 1158.3208984375
#                 , loss2: 992088.6
#                 , weight: 196580
# =================================
# in 1180 epoch, average loss: 228312320.0
#                 , loss1: 1157.04580078125
#                 , loss2: 987512.8
#                 , weight: 196380
# =================================
# in 1190 epoch, average loss: 227861504.0
#                 , loss1: 1155.925390625
#                 , loss2: 987991.5
#                 , weight: 196180
# =================================
# in 1200 epoch, average loss: 227387443.2
#                 , loss1: 1154.57685546875
#                 , loss2: 1009522.3
#                 , weight: 195980
# =================================
# in 1210 epoch, average loss: 226899865.6
#                 , loss1: 1153.434375
#                 , loss2: 976657.3
#                 , weight: 195780
# =================================
# in 1220 epoch, average loss: 226484121.6
#                 , loss1: 1152.46787109375
#                 , loss2: 980782.5
#                 , weight: 195580
# =================================
# in 1230 epoch, average loss: 226070374.4
#                 , loss1: 1151.51181640625
#                 , loss2: 984368.2
#                 , weight: 195380
# =================================
# in 1240 epoch, average loss: 225658982.4
#                 , loss1: 1150.64462890625
#                 , loss2: 972582.6
#                 , weight: 195180
# =================================
# in 1250 epoch, average loss: 225262464.0
#                 , loss1: 1149.85556640625
#                 , loss2: 960138.5
#                 , weight: 194980
# =================================
# in 1260 epoch, average loss: 224963788.8
#                 , loss1: 1149.4509765625
#                 , loss2: 970244.6
#                 , weight: 194780
# =================================
# in 1270 epoch, average loss: 224613376.0
#                 , loss1: 1148.76328125
#                 , loss2: 983625.2
#                 , weight: 194580
# =================================
# in 1280 epoch, average loss: 224113408.0
#                 , loss1: 1147.53408203125
#                 , loss2: 952447.4
#                 , weight: 194380
# =================================
# in 1290 epoch, average loss: 223768729.6
#                 , loss1: 1146.9748046875
#                 , loss2: 945917.2
#                 , weight: 194180
# =================================
# in 1300 epoch, average loss: 223378022.4
#                 , loss1: 1146.186328125
#                 , loss2: 937650.3
#                 , weight: 193980
# =================================
# in 1310 epoch, average loss: 223005670.4
#                 , loss1: 1145.48935546875
#                 , loss2: 929637.0
#                 , weight: 193780
# =================================
# in 1320 epoch, average loss: 222642406.4
#                 , loss1: 1144.8041015625
#                 , loss2: 928165.2
#                 , weight: 193580
# =================================
# in 1330 epoch, average loss: 222328217.6
#                 , loss1: 1144.3900390625
#                 , loss2: 923064.5
#                 , weight: 193380
# =================================
# in 1340 epoch, average loss: 221933875.2
#                 , loss1: 1143.5904296875
#                 , loss2: 912127.5
#                 , weight: 193180
# =================================
# in 1350 epoch, average loss: 221623424.0
#                 , loss1: 1143.17646484375
#                 , loss2: 910390.6
#                 , weight: 192980
# =================================
# in 1360 epoch, average loss: 221252249.6
#                 , loss1: 1142.44453125
#                 , loss2: 908970.5
#                 , weight: 192780
# =================================
# in 1370 epoch, average loss: 220895155.2
#                 , loss1: 1141.81123046875
#                 , loss2: 902358.4
#                 , weight: 192580
# =================================
# in 1380 epoch, average loss: 220593100.8
#                 , loss1: 1141.476171875
#                 , loss2: 893185.2
#                 , weight: 192380
# =================================
# in 1390 epoch, average loss: 220297676.8
#                 , loss1: 1141.06845703125
#                 , loss2: 904446.0
#                 , weight: 192180
# =================================
# in 1400 epoch, average loss: 219955891.2
#                 , loss1: 1140.52470703125
#                 , loss2: 895288.5
#                 , weight: 191980
# =================================
# in 1410 epoch, average loss: 219631897.6
#                 , loss1: 1140.07529296875
#                 , loss2: 885609.9
#                 , weight: 191780
# =================================
# in 1420 epoch, average loss: 219344384.0
#                 , loss1: 1139.74892578125
#                 , loss2: 888693.1
#                 , weight: 191580
# =================================
# in 1430 epoch, average loss: 218964300.8
#                 , loss1: 1139.04921875
#                 , loss2: 870525.9
#                 , weight: 191380
# =================================
# in 1440 epoch, average loss: 218703897.6
#                 , loss1: 1138.87470703125
#                 , loss2: 871370.7
#                 , weight: 191180
# =================================
# in 1450 epoch, average loss: 226676326.4
#                 , loss1: 1176.51171875
#                 , loss2: 1881957.4
#                 , weight: 190980
# =================================
# in 1460 epoch, average loss: 235524428.8
#                 , loss1: 1224.6564453125
#                 , loss2: 1773476.4
#                 , weight: 190780
# =================================
# in 1470 epoch, average loss: 227949337.6
#                 , loss1: 1187.9759765625
#                 , loss2: 1436872.9
#                 , weight: 190580
# =================================
# in 1480 epoch, average loss: 222103552.0
#                 , loss1: 1159.46484375
#                 , loss2: 1260020.4
#                 , weight: 190380
# =================================
# in 1490 epoch, average loss: 219562572.8
#                 , loss1: 1148.12958984375
#                 , loss2: 1107820.7
#                 , weight: 190180
# =================================
# in 1500 epoch, average loss: 217994444.8
#                 , loss1: 1141.03193359375
#                 , loss2: 1118390.1
#                 , weight: 189980
# =================================
# in 1510 epoch, average loss: 216851225.6
#                 , loss1: 1136.97041015625
#                 , loss2: 974595.1
#                 , weight: 189780
# =================================
# in 1520 epoch, average loss: 216118988.8
#                 , loss1: 1134.3490234375
#                 , loss2: 966962.9
#                 , weight: 189580
# =================================
# in 1530 epoch, average loss: 215562572.8
#                 , loss1: 1132.78125
#                 , loss2: 934469.2
#                 , weight: 189380
# =================================
# in 1540 epoch, average loss: 215136972.8
#                 , loss1: 1131.83232421875
#                 , loss2: 915052.3
#                 , weight: 189180
# =================================
# in 1550 epoch, average loss: 214745523.2
#                 , loss1: 1131.0419921875
#                 , loss2: 899400.0
#                 , weight: 188980
# =================================
# in 1560 epoch, average loss: 214393894.4
#                 , loss1: 1130.40908203125
#                 , loss2: 893531.5
#                 , weight: 188780
# =================================
# in 1570 epoch, average loss: 214039449.6
#                 , loss1: 1129.7634765625
#                 , loss2: 886967.7
#                 , weight: 188580
# =================================
# in 1580 epoch, average loss: 213717184.0
#                 , loss1: 1129.2705078125
#                 , loss2: 883551.0
#                 , weight: 188380
# =================================
# in 1590 epoch, average loss: 213405504.0
#                 , loss1: 1128.8703125
#                 , loss2: 873065.1
#                 , weight: 188180
# =================================
# in 1600 epoch, average loss: 213088486.4
#                 , loss1: 1128.406640625
#                 , loss2: 869036.0
#                 , weight: 187980
# =================================
# in 1610 epoch, average loss: 212783321.6
#                 , loss1: 1128.028515625
#                 , loss2: 860607.6
#                 , weight: 187780
# =================================
# in 1620 epoch, average loss: 212484096.0
#                 , loss1: 1127.64658203125
#                 , loss2: 858662.1
#                 , weight: 187580
# =================================
# in 1630 epoch, average loss: 212195916.8
#                 , loss1: 1127.3384765625
#                 , loss2: 853806.3
#                 , weight: 187380
# =================================
# in 1640 epoch, average loss: 211879590.4
#                 , loss1: 1126.8958984375
#                 , loss2: 845804.6
#                 , weight: 187180
# =================================
# in 1650 epoch, average loss: 211589516.8
#                 , loss1: 1126.58642578125
#                 , loss2: 838979.2
#                 , weight: 186980
# =================================
# in 1660 epoch, average loss: 211291008.0
#                 , loss1: 1126.2224609375
#                 , loss2: 833840.85
#                 , weight: 186780
# =================================
# in 1670 epoch, average loss: 211026880.0
#                 , loss1: 1126.03037109375
#                 , loss2: 830793.05
#                 , weight: 186580
# =================================
# in 1680 epoch, average loss: 210731225.6
#                 , loss1: 1125.67080078125
#                 , loss2: 827383.0
#                 , weight: 186380
# =================================
# in 1690 epoch, average loss: 210432307.2
#                 , loss1: 1125.2904296875
#                 , loss2: 824461.5
#                 , weight: 186180
# =================================
# in 1700 epoch, average loss: 210157491.2
#                 , loss1: 1125.0583984375
#                 , loss2: 817902.8
#                 , weight: 185980
# =================================
# in 1710 epoch, average loss: 209882560.0
#                 , loss1: 1124.81376953125
#                 , loss2: 813413.7
#                 , weight: 185780
# =================================
# in 1720 epoch, average loss: 209599142.4
#                 , loss1: 1124.516796875
#                 , loss2: 810087.65
#                 , weight: 185580
# =================================
# in 1730 epoch, average loss: 209312012.8
#                 , loss1: 1124.19755859375
#                 , loss2: 807101.05
#                 , weight: 185380
# =================================
# in 1740 epoch, average loss: 209030156.8
#                 , loss1: 1123.9224609375
#                 , loss2: 801005.95
#                 , weight: 185180
# =================================
# in 1750 epoch, average loss: 208778969.6
#                 , loss1: 1123.794140625
#                 , loss2: 798381.2
#                 , weight: 184980
# =================================
# in 1760 epoch, average loss: 208491635.2
#                 , loss1: 1123.458984375
#                 , loss2: 797777.85
#                 , weight: 184780
# =================================
# in 1770 epoch, average loss: 208218713.6
#                 , loss1: 1123.24931640625
#                 , loss2: 788264.1
#                 , weight: 184580
# =================================
# in 1780 epoch, average loss: 207927296.0
#                 , loss1: 1122.900390625
#                 , loss2: 785879.6
#                 , weight: 184380
# =================================
# in 1790 epoch, average loss: 207675276.8
#                 , loss1: 1122.75849609375
#                 , loss2: 784574.0
#                 , weight: 184180
# =================================
# in 1800 epoch, average loss: 207401177.6
#                 , loss1: 1122.51796875
#                 , loss2: 779317.8
#                 , weight: 183980
# =================================
# in 1810 epoch, average loss: 207127398.4
#                 , loss1: 1122.27060546875
#                 , loss2: 775475.6
#                 , weight: 183780
# =================================
# in 1820 epoch, average loss: 206861926.4
#                 , loss1: 1122.06240234375
#                 , loss2: 772731.7
#                 , weight: 183580
# =================================
# in 1830 epoch, average loss: 206593292.8
#                 , loss1: 1121.84189453125
#                 , loss2: 768935.1
#                 , weight: 183380
# =================================
# in 1840 epoch, average loss: 206319872.0
#                 , loss1: 1121.5984375
#                 , loss2: 764535.5
#                 , weight: 183180
# =================================
# in 1850 epoch, average loss: 206037260.8
#                 , loss1: 1121.28974609375
#                 , loss2: 762739.65
#                 , weight: 182980
# =================================
# in 1860 epoch, average loss: 205784563.2
#                 , loss1: 1121.14091796875
#                 , loss2: 761525.5
#                 , weight: 182780
# =================================
# in 1870 epoch, average loss: 205515635.2
#                 , loss1: 1120.94775390625
#                 , loss2: 752110.25
#                 , weight: 182580
# =================================
# in 1880 epoch, average loss: 205231923.2
#                 , loss1: 1120.623828125
#                 , loss2: 751702.1
#                 , weight: 182380
# =================================
# in 1890 epoch, average loss: 204988697.6
#                 , loss1: 1120.5455078125
#                 , loss2: 746877.5
#                 , weight: 182180
# =================================
# in 1900 epoch, average loss: 204746611.2
#                 , loss1: 1120.46328125
#                 , loss2: 743867.1
#                 , weight: 181980
# =================================
# in 1910 epoch, average loss: 204463782.4
#                 , loss1: 1120.15810546875
#                 , loss2: 740614.7
#                 , weight: 181780
# =================================
# in 1920 epoch, average loss: 204219724.8
#                 , loss1: 1120.05439453125
#                 , loss2: 739455.75
#                 , weight: 181580
# =================================
# in 1930 epoch, average loss: 203946739.2
#                 , loss1: 1119.8072265625
#                 , loss2: 735312.3
#                 , weight: 181380
# =================================
# in 1940 epoch, average loss: 203680115.2
#                 , loss1: 1119.586328125
#                 , loss2: 732693.9
#                 , weight: 181180
# =================================
# in 1950 epoch, average loss: 203425292.8
#                 , loss1: 1119.438671875
#                 , loss2: 728541.4
#                 , weight: 180980
# =================================
# in 1960 epoch, average loss: 203162124.8
#                 , loss1: 1119.25078125
#                 , loss2: 723225.1
#                 , weight: 180780
# =================================
# in 1970 epoch, average loss: 202907929.6
#                 , loss1: 1119.081640625
#                 , loss2: 723443.65
#                 , weight: 180580
# =================================
# in 1980 epoch, average loss: 202638400.0
#                 , loss1: 1118.8833984375
#                 , loss2: 713526.1
#                 , weight: 180380
# =================================
# in 1990 epoch, average loss: 202393958.4
#                 , loss1: 1118.768359375
#                 , loss2: 713576.4
#                 , weight: 180180
# =================================
# in 2000 epoch, average loss: 202131302.4
#                 , loss1: 1118.5404296875
#                 , loss2: 715717.25
#                 , weight: 179980
# =================================
# in 2010 epoch, average loss: 201884531.2
#                 , loss1: 1118.45859375
#                 , loss2: 707409.55
#                 , weight: 179780
# =================================
# in 2020 epoch, average loss: 201631168.0
#                 , loss1: 1118.3076171875
#                 , loss2: 704816.05
#                 , weight: 179580
# =================================
# in 2030 epoch, average loss: 201353881.6
#                 , loss1: 1118.03515625
#                 , loss2: 700091.4
#                 , weight: 179380
# =================================
# in 2040 epoch, average loss: 201109401.6
#                 , loss1: 1117.94052734375
#                 , loss2: 696185.35
#                 , weight: 179180
# =================================
# in 2050 epoch, average loss: 200852902.4
#                 , loss1: 1117.757421875
#                 , loss2: 696067.0
#                 , weight: 178980
# =================================
# in 2060 epoch, average loss: 200615692.8
#                 , loss1: 1117.68642578125
#                 , loss2: 695120.1
#                 , weight: 178780
# =================================
# in 2070 epoch, average loss: 200342617.6
#                 , loss1: 1117.449609375
#                 , loss2: 687900.05
#                 , weight: 178580
# =================================
# in 2080 epoch, average loss: 200090291.2
#                 , loss1: 1117.3015625
#                 , loss2: 685471.2
#                 , weight: 178380
# =================================
# in 2090 epoch, average loss: 199839257.6
#                 , loss1: 1117.149609375
#                 , loss2: 684983.9
#                 , weight: 178180
# =================================
# in 2100 epoch, average loss: 199581017.6
#                 , loss1: 1116.946484375
#                 , loss2: 686375.8
#                 , weight: 177980
# =================================
# in 2110 epoch, average loss: 199324096.0
#                 , loss1: 1116.7568359375
#                 , loss2: 686530.55
#                 , weight: 177780
# =================================
# in 2120 epoch, average loss: 199047692.8
#                 , loss1: 1116.5134765625
#                 , loss2: 676769.75
#                 , weight: 177580
# =================================
# in 2130 epoch, average loss: 198784678.4
#                 , loss1: 1116.2994140625
#                 , loss2: 675029.35
#                 , weight: 177380
# =================================
# in 2140 epoch, average loss: 198534592.0
#                 , loss1: 1116.17470703125
#                 , loss2: 670297.2
#                 , weight: 177180
# =================================
# in 2150 epoch, average loss: 198274124.8
#                 , loss1: 1115.98359375
#                 , loss2: 666925.95
#                 , weight: 176980
# =================================
# in 2160 epoch, average loss: 198024908.8
#                 , loss1: 1115.872265625
#                 , loss2: 660569.3
#                 , weight: 176780
# =================================
# in 2170 epoch, average loss: 197778406.4
#                 , loss1: 1115.72939453125
#                 , loss2: 662495.45
#                 , weight: 176580
# =================================
# in 2180 epoch, average loss: 197532339.2
#                 , loss1: 1115.61494140625
#                 , loss2: 659764.3
#                 , weight: 176380
# =================================
# in 2190 epoch, average loss: 197286745.6
#                 , loss1: 1115.5064453125
#                 , loss2: 656436.6
#                 , weight: 176180
# =================================
# in 2200 epoch, average loss: 197030809.6
#                 , loss1: 1115.34482421875
#                 , loss2: 652038.8
#                 , weight: 175980
# =================================
# in 2210 epoch, average loss: 196767552.0
#                 , loss1: 1115.15361328125
#                 , loss2: 645503.6
#                 , weight: 175780
# =================================
# in 2220 epoch, average loss: 196540800.0
#                 , loss1: 1115.15703125
#                 , loss2: 641174.5
#                 , weight: 175580
# =================================
# in 2230 epoch, average loss: 196277491.2
#                 , loss1: 1114.9279296875
#                 , loss2: 641083.9
#                 , weight: 175380
# =================================
# in 2240 epoch, average loss: 196037798.4
#                 , loss1: 1114.83173828125
#                 , loss2: 641224.3
#                 , weight: 175180
# =================================
# in 2250 epoch, average loss: 195789337.6
#                 , loss1: 1114.7087890625
#                 , loss2: 637276.0
#                 , weight: 174980
# =================================
# in 2260 epoch, average loss: 195543654.4
#                 , loss1: 1114.61689453125
#                 , loss2: 630615.65
#                 , weight: 174780
# =================================
# in 2270 epoch, average loss: 195289881.6
#                 , loss1: 1114.4208984375
#                 , loss2: 633971.35
#                 , weight: 174580
# =================================
# in 2280 epoch, average loss: 195048806.4
#                 , loss1: 1114.3525390625
#                 , loss2: 627705.3
#                 , weight: 174380
# =================================
# in 2290 epoch, average loss: 194794675.2
#                 , loss1: 1114.17822265625
#                 , loss2: 626834.45
#                 , weight: 174180
# =================================
# in 2300 epoch, average loss: 194565657.6
#                 , loss1: 1114.16611328125
#                 , loss2: 622750.1
#                 , weight: 173980
# =================================
# in 2310 epoch, average loss: 194310348.8
#                 , loss1: 1113.9896484375
#                 , loss2: 620941.75
#                 , weight: 173780
# =================================
# in 2320 epoch, average loss: 194063987.2
#                 , loss1: 1113.9056640625
#                 , loss2: 611999.1
#                 , weight: 173580
# =================================
# in 2330 epoch, average loss: 193829990.4
#                 , loss1: 1113.824609375
#                 , loss2: 614822.2
#                 , weight: 173380
# =================================
# in 2340 epoch, average loss: 193577075.2
#                 , loss1: 1113.65556640625
#                 , loss2: 613963.65
#                 , weight: 173180
# =================================
# in 2350 epoch, average loss: 193325619.2
#                 , loss1: 1113.5345703125
#                 , loss2: 606165.5
#                 , weight: 172980
# =================================
# in 2360 epoch, average loss: 193099020.8
#                 , loss1: 1113.49541015625
#                 , loss2: 609067.2
#                 , weight: 172780
# =================================
# in 2370 epoch, average loss: 192842188.8
#                 , loss1: 1113.33408203125
#                 , loss2: 602792.95
#                 , weight: 172580
# =================================
# in 2380 epoch, average loss: 192597747.2
#                 , loss1: 1113.233984375
#                 , loss2: 598252.85
#                 , weight: 172380
# =================================
# in 2390 epoch, average loss: 192365747.2
#                 , loss1: 1113.17802734375
#                 , loss2: 598554.75
#                 , weight: 172180
# =================================
# in 2400 epoch, average loss: 192122240.0
#                 , loss1: 1113.082421875
#                 , loss2: 594112.85
#                 , weight: 171980
# =================================
# in 2410 epoch, average loss: 191873574.4
#                 , loss1: 1112.93798828125
#                 , loss2: 592939.7
#                 , weight: 171780
# =================================
# in 2420 epoch, average loss: 191635276.8
#                 , loss1: 1112.88154296875
#                 , loss2: 586889.3
#                 , weight: 171580
# =================================
# in 2430 epoch, average loss: 191379635.2
#                 , loss1: 1112.6751953125
#                 , loss2: 589211.0
#                 , weight: 171380
# =================================
# in 2440 epoch, average loss: 191146700.8
#                 , loss1: 1112.65087890625
#                 , loss2: 582970.25
#                 , weight: 171180
# =================================
# in 2450 epoch, average loss: 190904806.4
#                 , loss1: 1112.55390625
#                 , loss2: 580209.5
#                 , weight: 170980
# =================================
# in 2460 epoch, average loss: 190663552.0
#                 , loss1: 1112.46064453125
#                 , loss2: 577419.3
#                 , weight: 170780
# =================================
# in 2470 epoch, average loss: 190420761.6
#                 , loss1: 1112.37001953125
#                 , loss2: 572573.5
#                 , weight: 170580
# =================================
# in 2480 epoch, average loss: 190170854.4
#                 , loss1: 1112.19658203125
#                 , loss2: 574727.65
#                 , weight: 170380
# =================================
# in 2490 epoch, average loss: 189926860.8
#                 , loss1: 1112.11201171875
#                 , loss2: 567536.3
#                 , weight: 170180
# =================================
# in 2500 epoch, average loss: 189685888.0
#                 , loss1: 1112.01376953125
#                 , loss2: 565719.55
#                 , weight: 169980
# =================================
# in 2510 epoch, average loss: 189440422.4
#                 , loss1: 1111.8654296875
#                 , loss2: 567842.6
#                 , weight: 169780
# =================================
# in 2520 epoch, average loss: 189198579.2
#                 , loss1: 1111.78330078125
#                 , loss2: 562312.65
#                 , weight: 169580
# =================================
# in 2530 epoch, average loss: 188951859.2
#                 , loss1: 1111.6376953125
#                 , loss2: 562626.8
#                 , weight: 169380
# =================================
# in 2540 epoch, average loss: 188693632.0
#                 , loss1: 1111.455859375
#                 , loss2: 557496.9
#                 , weight: 169180
# =================================
# in 2550 epoch, average loss: 188456614.4
#                 , loss1: 1111.35771484375
#                 , loss2: 559355.0
#                 , weight: 168980
# =================================
# in 2560 epoch, average loss: 188193958.4
#                 , loss1: 1111.13623046875
#                 , loss2: 556392.75
#                 , weight: 168780
# =================================
# in 2570 epoch, average loss: 187957657.6
#                 , loss1: 1111.02197265625
#                 , loss2: 561554.7
#                 , weight: 168580
# =================================
# in 2580 epoch, average loss: 187686182.4
#                 , loss1: 1110.7455078125
#                 , loss2: 558886.4
#                 , weight: 168380
# =================================
# in 2590 epoch, average loss: 187445312.0
#                 , loss1: 1110.5869140625
#                 , loss2: 566841.1
#                 , weight: 168180
# =================================
# in 2600 epoch, average loss: 187184921.6
#                 , loss1: 1110.3525390625
#                 , loss2: 567959.2
#                 , weight: 167980
# =================================
# in 2610 epoch, average loss: 186937561.6
#                 , loss1: 1110.18720703125
#                 , loss2: 570411.5
#                 , weight: 167780
# =================================
# ...
#                 , loss1: 1163.67890625
#                 , loss2: 9.674141693115235
#                 , weight: 20.0
# =================================
# in 15830 epoch, average loss: 23284.3921875
#                 , loss1: 1163.5765625
#                 , loss2: 12.8611083984375
#                 , weight: 20.0
# =================================
# in 15840 epoch, average loss: 23293.7765625
#                 , loss1: 1163.93525390625
#                 , loss2: 15.071926879882813
#                 , weight: 20.0
# =================================
# in 15850 epoch, average loss: 23280.3203125
#                 , loss1: 1163.191796875
#                 , loss2: 16.483401489257812
#                 , weight: 20.0
# =================================
# in 15860 epoch, average loss: 23281.6578125
#                 , loss1: 1163.02861328125
#                 , loss2: 21.085581970214843
#                 , weight: 20.0
# =================================
# in 15870 epoch, average loss: 23283.90625
#                 , loss1: 1163.1609375
#                 , loss2: 20.685531616210938
#                 , weight: 20.0
# =================================
# in 15880 epoch, average loss: 23267.1421875
#                 , loss1: 1162.6396484375
#                 , loss2: 14.346591186523437
#                 , weight: 20.0
# =================================
# in 15890 epoch, average loss: 23264.31875
#                 , loss1: 1162.8244140625
#                 , loss2: 7.828440093994141
#                 , weight: 20.0
# =================================
# in 15900 epoch, average loss: 23271.309375
#                 , loss1: 1162.3578125
#                 , loss2: 24.152523803710938
#                 , weight: 20.0
# =================================
# in 15910 epoch, average loss: 23284.7078125
#                 , loss1: 1162.66220703125
#                 , loss2: 31.462283325195312
#                 , weight: 20.0
# =================================
# in 15920 epoch, average loss: 23270.471875
#                 , loss1: 1162.20703125
#                 , loss2: 26.329925537109375
#                 , weight: 20.0
# =================================
# in 15930 epoch, average loss: 23275.5953125
#                 , loss1: 1162.4390625
#                 , loss2: 26.81485595703125
#                 , weight: 20.0
# =================================
# in 15940 epoch, average loss: 23268.803125
#                 , loss1: 1161.99990234375
#                 , loss2: 28.80323181152344
#                 , weight: 20.0
# =================================
# in 15950 epoch, average loss: 23251.6515625
#                 , loss1: 1161.96953125
#                 , loss2: 12.259176635742188
#                 , weight: 20.0
# =================================
# in 15960 epoch, average loss: 23249.609375
#                 , loss1: 1162.078515625
#                 , loss2: 8.038469696044922
#                 , weight: 20.0
# =================================
# in 15970 epoch, average loss: 23247.209375
#                 , loss1: 1161.58447265625
#                 , loss2: 15.52074737548828
#                 , weight: 20.0
# =================================
# in 15980 epoch, average loss: 23258.4734375
#                 , loss1: 1162.24892578125
#                 , loss2: 13.493733215332032
#                 , weight: 20.0
# =================================
# in 15990 epoch, average loss: 23266.1828125
#                 , loss1: 1161.49951171875
#                 , loss2: 36.194921875
#                 , weight: 20.0
# =================================
# in 16000 epoch, average loss: 23247.8484375
#                 , loss1: 1161.88095703125
#                 , loss2: 10.228082275390625
#                 , weight: 20.0
# =================================
# in 16010 epoch, average loss: 23247.9984375
#                 , loss1: 1161.44912109375
#                 , loss2: 19.012911987304687
#                 , weight: 20.0
# =================================
# in 16020 epoch, average loss: 23244.6203125
#                 , loss1: 1161.683984375
#                 , loss2: 10.939686584472657
#                 , weight: 20.0
# =================================
# in 16030 epoch, average loss: 23231.4171875
#                 , loss1: 1161.154296875
#                 , loss2: 8.332470703125
#                 , weight: 20.0
# =================================
# in 16040 epoch, average loss: 23239.7359375
#                 , loss1: 1161.15927734375
#                 , loss2: 16.551402282714843
#                 , weight: 20.0
# =================================
# in 16050 epoch, average loss: 23228.66875
#                 , loss1: 1160.7185546875
#                 , loss2: 14.298764038085938
#                 , weight: 20.0
# =================================
# in 16060 epoch, average loss: 23230.0484375
#                 , loss1: 1160.8517578125
#                 , loss2: 13.013632202148438
#                 , weight: 20.0
# =================================
# in 16070 epoch, average loss: 23242.609375
#                 , loss1: 1161.13115234375
#                 , loss2: 19.989334106445312
#                 , weight: 20.0
# =================================
# in 16080 epoch, average loss: 23225.7375
#                 , loss1: 1160.93134765625
#                 , loss2: 7.107700347900391
#                 , weight: 20.0
# =================================
# in 16090 epoch, average loss: 23229.06875
#                 , loss1: 1160.52822265625
#                 , loss2: 18.505653381347656
#                 , weight: 20.0
# =================================
# in 16100 epoch, average loss: 23226.996875
#                 , loss1: 1160.45732421875
#                 , loss2: 17.84553680419922
#                 , weight: 20.0
# =================================
# in 16110 epoch, average loss: 23217.1421875
#                 , loss1: 1160.41611328125
#                 , loss2: 8.822077178955078
#                 , weight: 20.0
# =================================
# in 16120 epoch, average loss: 23217.040625
#                 , loss1: 1160.398046875
#                 , loss2: 9.076959991455078
#                 , weight: 20.0
# =================================
# in 16130 epoch, average loss: 23225.178125
#                 , loss1: 1160.4318359375
#                 , loss2: 16.54057922363281
#                 , weight: 20.0
# =================================
# in 16140 epoch, average loss: 23215.3921875
#                 , loss1: 1160.04111328125
#                 , loss2: 14.567691040039062
#                 , weight: 20.0
# =================================
# in 16150 epoch, average loss: 23213.646875
#                 , loss1: 1160.28251953125
#                 , loss2: 7.996720886230468
#                 , weight: 20.0
# =================================
# in 16160 epoch, average loss: 23211.721875
#                 , loss1: 1160.19091796875
#                 , loss2: 7.903769683837891
#                 , weight: 20.0
# =================================
# in 16170 epoch, average loss: 23213.6
#                 , loss1: 1159.778515625
#                 , loss2: 18.029437255859374
#                 , weight: 20.0
# =================================
# in 16180 epoch, average loss: 23211.815625
#                 , loss1: 1159.992578125
#                 , loss2: 11.962416076660157
#                 , weight: 20.0
# =================================
# in 16190 epoch, average loss: 23215.8578125
#                 , loss1: 1159.97841796875
#                 , loss2: 16.286309814453126
#                 , weight: 20.0
# =================================
# in 16200 epoch, average loss: 23196.8828125
#                 , loss1: 1159.4556640625
#                 , loss2: 7.771131134033203
#                 , weight: 20.0
# =================================
# in 16210 epoch, average loss: 23207.60625
#                 , loss1: 1159.73603515625
#                 , loss2: 12.8870361328125
#                 , weight: 20.0
# =================================
# in 16220 epoch, average loss: 23199.6015625
#                 , loss1: 1159.62294921875
#                 , loss2: 7.142984771728516
#                 , weight: 20.0
# =================================
# in 16230 epoch, average loss: 23207.4265625
#                 , loss1: 1159.64541015625
#                 , loss2: 14.515432739257813
#                 , weight: 20.0
# =================================
# in 16240 epoch, average loss: 23203.1890625
#                 , loss1: 1159.3611328125
#                 , loss2: 15.965745544433593
#                 , weight: 20.0
# =================================
# in 16250 epoch, average loss: 23207.39375
#                 , loss1: 1159.64423828125
#                 , loss2: 14.509138488769532
#                 , weight: 20.0
# =================================
# in 16260 epoch, average loss: 23192.68125
#                 , loss1: 1159.1990234375
#                 , loss2: 8.703063201904296
#                 , weight: 20.0
# =================================
# in 16270 epoch, average loss: 23200.171875
#                 , loss1: 1159.3189453125
#                 , loss2: 13.79044189453125
#                 , weight: 20.0
# =================================
# in 16280 epoch, average loss: 23198.971875
#                 , loss1: 1158.90654296875
#                 , loss2: 20.83881378173828
#                 , weight: 20.0
# =================================
# in 16290 epoch, average loss: 23191.2140625
#                 , loss1: 1158.86083984375
#                 , loss2: 13.998069763183594
#                 , weight: 20.0
# =================================
# in 16300 epoch, average loss: 23216.015625
#                 , loss1: 1159.201953125
#                 , loss2: 31.977532958984376
#                 , weight: 20.0
# =================================
# in 16310 epoch, average loss: 23190.8390625
#                 , loss1: 1159.1486328125
#                 , loss2: 7.8644767761230465
#                 , weight: 20.0
# =================================
# in 16320 epoch, average loss: 23195.0359375
#                 , loss1: 1159.06572265625
#                 , loss2: 13.72149200439453
#                 , weight: 20.0
# =================================
# in 16330 epoch, average loss: 23188.0609375
#                 , loss1: 1158.68349609375
#                 , loss2: 14.391917419433593
#                 , weight: 20.0
# =================================
# in 16340 epoch, average loss: 23188.684375
#                 , loss1: 1158.42490234375
#                 , loss2: 20.182794189453126
#                 , weight: 20.0
# =================================
# in 16350 epoch, average loss: 23179.690625
#                 , loss1: 1158.48642578125
#                 , loss2: 9.96146011352539
#                 , weight: 20.0
# =================================
# in 16360 epoch, average loss: 23175.9171875
#                 , loss1: 1158.48505859375
#                 , loss2: 6.213806533813477
#                 , weight: 20.0
# =================================
# in 16370 epoch, average loss: 23181.340625
#                 , loss1: 1158.2478515625
#                 , loss2: 16.382937622070312
#                 , weight: 20.0
# =================================
# in 16380 epoch, average loss: 23175.8921875
#                 , loss1: 1158.243359375
#                 , loss2: 11.022457122802734
#                 , weight: 20.0
# =================================
# in 16390 epoch, average loss: 23184.7734375
#                 , loss1: 1158.12314453125
#                 , loss2: 22.30767364501953
#                 , weight: 20.0
# =================================
# in 16400 epoch, average loss: 23179.2046875
#                 , loss1: 1158.09990234375
#                 , loss2: 17.206065368652343
#                 , weight: 20.0
# =================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 11
#       9 elif hgnn_trainer.weight < limit:
#      10     hgnn_trainer.weight = limit
# ---> 11 loss, loss_1, loss_2 = hgnn_trainer.run(epoch=epoch)
#      12 temp_loss_total += loss
#      13 temp_loss1 += loss_1
#
# Cell In[17], line 30, in Trainer.run(self, epoch)
#      28 self.train()  # train mode | 设置为训练模式
#      29 self.optimizer.zero_grad()
# ---> 30 outs = self.forward(self.X)
#      31 loss, loss_1, loss_2 = loss_bs_matrix(outs, self.hg, device=DEVICE,weight=self.weight)
#      32 loss.backward()
#
# Cell In[17], line 22, in Trainer.forward(self, X)
#      21 def forward(self, X):
# ---> 22     X = self.layers[0](X, self.hg)
#      23     for layer in self.layers[1:]:
#      24         X = layer(X)
#
# File ~/.conda/envs/partition/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/work/Hyper-Graph-Partition/examples_standardForm/../hgp/models.py:174, in HGNNP.forward(self, X, hg)
#     167 r"""The forward function.
#     168
#     169 Args:
#     170     ``X`` (``torch.Tensor``): Input vertex feature matrix. Size :math:`(N, C_{in})`.
#     171     ``hg`` (``dhg.Hypergraph``): The hypergraph structure that contains :math:`N` vertices.
#     172 """
#     173 for layer in self.layers:
# --> 174     X = layer(X, hg)
#     175 return X
#
# File ~/.conda/envs/partition/lib/python3.10/site-packages/torch/nn/modules/module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/partition/lib/python3.10/site-packages/dhg/nn/convs/hypergraphs/hgnnp_conv.py:62, in HGNNPConv.forward(self, X, hg)
#      55 r"""The forward function.
#      56
#      57 Args:
#      58     X (``torch.Tensor``): Input vertex feature matrix. Size :math:`(|\mathcal{V}|, C_{in})`.
#      59     hg (``dhg.Hypergraph``): The hypergraph structure that contains :math:`|\mathcal{V}|` vertices.
#      60 """
#      61 X = self.theta(X)
# ---> 62 X = hg.v2v(X, aggr="mean")
#      63 if not self.is_last:
#      64     X = self.act(X)
#
# File ~/.conda/envs/partition/lib/python3.10/site-packages/dhg/structure/hypergraphs/hypergraph.py:1656, in Hypergraph.v2v(self, X, aggr, drop_rate, v2e_aggr, v2e_weight, v2e_drop_rate, e_weight, e2v_aggr, e2v_weight, e2v_drop_rate)
#    1654 if e2v_drop_rate is None:
#    1655     e2v_drop_rate = drop_rate
# -> 1656 X = self.v2e(X, v2e_aggr, v2e_weight, e_weight, drop_rate=v2e_drop_rate)
#    1657 X = self.e2v(X, e2v_aggr, e2v_weight, drop_rate=e2v_drop_rate)
#    1658 return X
#
# File ~/.conda/envs/partition/lib/python3.10/site-packages/dhg/structure/hypergraphs/hypergraph.py:1418, in Hypergraph.v2e(self, X, aggr, v2e_weight, e_weight, drop_rate)
#    1401 def v2e(
#    1402     self,
#    1403     X: torch.Tensor,
#    (...)
#    1407     drop_rate: float = 0.0,
#    1408 ):
#    1409     r"""Message passing of ``vertices to hyperedges``. The combination of ``v2e_aggregation`` and ``v2e_update``.
#    1410
#    1411     Args:
#    (...)
#    1416         ``drop_rate`` (``float``): Dropout rate. Randomly dropout the connections in incidence matrix with probability ``drop_rate``. Default: ``0.0``.
#    1417     """
# -> 1418     X = self.v2e_aggregation(X, aggr, v2e_weight, drop_rate=drop_rate)
#    1419     X = self.v2e_update(X, e_weight)
#    1420     return X
#
# File ~/.conda/envs/partition/lib/python3.10/site-packages/dhg/structure/hypergraphs/hypergraph.py:1267, in Hypergraph.v2e_aggregation(self, X, aggr, v2e_weight, drop_rate)
#    1265     P = self.H_T
#    1266 if aggr == "mean":
# -> 1267     X = torch.sparse.mm(P, X)
#    1268     X = torch.sparse.mm(self.D_e_neg_1, X)
#    1269 elif aggr == "sum":
#
# KeyboardInterrupt:

# %%
hgnn_trainer.eval()
outs = hgnn_trainer.forward(hgnn_trainer.X)
outs_straight = StraightThroughEstimator.apply(outs)
G_clone = G.clone()
edges, _  = G_clone.e
cut = 0
for vertices in edges:
    if torch.prod(outs_straight[list(vertices)], dim=0).sum() == 0:
        cut += 1
    else:
        G_clone.remove_hyperedges(vertices)
assert cut == G_clone.num_e
cut
# Out:
# 1102

# %%
num_nodes = outs_straight.sum(dim=0)
print(num_nodes)
# Out:
# tensor([3693., 3710.], device='cuda:0', grad_fn=<SumBackward1>)
