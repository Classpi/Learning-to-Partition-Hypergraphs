# %%
import sys
sys.path.append("../")

# %%
import torch
import torch.optim as optim
from torch import nn

import hgp
from hgp.models import HGNNP,CHGNN
from hgp.function import StraightThroughEstimator

import numpy as np
import random
DEVICE = torch.device("cuda:1") if torch.cuda.is_available() else torch.device("cpu")
DEVICE
# Out:
# device(type='cuda', index=1)

# %%
seed = 42
torch.manual_seed(seed) 
torch.cuda.manual_seed(seed) 
torch.cuda.manual_seed_all(seed) 
np.random.seed(seed)  
random.seed(seed) 
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = False

# %%
from hgp.models import ParameterDict

# fmt: off
h_hyper_prmts = ParameterDict()
l_hyper_prmts = ParameterDict()

partitions = 3

weight = 220000
limit = 20
sub = 20
lr = 4e-5

h_hyper_prmts["convlayers1"] = {"in_channels": 7000, "out_channels": 2048, "use_bn": False, "drop_rate": 0.8}
h_hyper_prmts["convlayers1"] = {"in_channels": 2048, "out_channels": 1024, "use_bn": False, "drop_rate": 0}
h_hyper_prmts["convlayers12"] = {"in_channels": 1024, "out_channels": 512, "use_bn": False, "drop_rate": 0}
h_hyper_prmts["convlayers14"] = {"in_channels": 512, "out_channels": 256, "use_bn": False, "drop_rate": 0}
h_hyper_prmts["convlayers13"] = {"in_channels": 256, "out_channels": 128, "use_bn": False, "drop_rate": 0}
# h_hyper_prmts["convlayers131"] = {"in_channels": 128, "out_channels": 64, "use_bn": False, "drop_rate": 0}


l_hyper_prmts["linerlayer1"] = {"in_channels":list(h_hyper_prmts.values())[-1]["out_channels"], "out_channels":64, "use_bn":False, "drop_rate":0.05}
l_hyper_prmts["linerlayer42"] = {"in_channels":64, "out_channels":32, "use_bn":False, "drop_rate":0.05}
l_hyper_prmts["linerlayer421"] = {"in_channels":32, "out_channels":16, "use_bn":False, "drop_rate":0.05}
# l_hyper_prmts["linerlayer422"] = {"in_channels":16, "out_channels":8, "use_bn":False, "drop_rate":0.05}
l_hyper_prmts["linerlayer423"] = {"in_channels":16, "out_channels":3, "use_bn":True, "drop_rate":0}



hyper = {
    "h_hyper_prmts": h_hyper_prmts,
    "l_hyper_prmts":l_hyper_prmts,
    "init_features_dim":list(h_hyper_prmts.values())[0]["in_channels"],
    "partitions":partitions
}

# fmt: on

# %%
def loss_bs_matrix(outs, hg, device, weight):

    H = hg.H.to_dense().to(device)
    outs = outs.to(device)

    X_ = outs.t().unsqueeze(-1)
    H_ = H.unsqueeze(0)
    xweight = H.sum(dim=0)
    mid = X_.mul(H_)
    sum = (mid * (1 / xweight)).sum()
    sub = (mid + (1 - H)).prod(dim=1).sum()
    loss_1 = sum - sub

    loss_2 = torch.var(torch.sum(outs, dim=0)).to(device)
    loss = weight * loss_1 + loss_2

    return loss, loss_1, loss_2

# %%
class Trainer(nn.Module):

    def __init__(self, net, X, hg, optimizer):
        super().__init__()
        self.X: torch.Tensor = X.to(DEVICE)
        self.hg = hg.to(DEVICE)
        self.de = self.hg.H.to_dense().sum(dim=0).to("cpu").to(DEVICE)
        self.optimizer: torch.optim.Optimizer = optimizer
        self.layers = nn.ModuleList()
        self.layers.append(net.to(DEVICE))
        self.weight = 200
    def forward(self, X):
        X = self.layers[0](X, self.hg)
        for layer in self.layers[1:]:
            X = layer(X)
        return X

    def run(self, epoch):
        self.train()  
        self.optimizer.zero_grad()
        outs = self.forward(self.X)
        loss, loss_1, loss_2 = loss_bs_matrix(outs, self.hg, device=DEVICE,weight=self.weight)
        loss.backward()
        self.optimizer.step()

        return loss.item(), loss_1.item(), loss_2.item()

# %%
import dhg 
from dhg.data import Cooking200
data = Cooking200()
e_list = data["edge_list"]
num_v = data["num_vertices"]
G = dhg.Hypergraph(data["num_vertices"],data["edge_list"])
num_v, data["num_edges"]
# Out:
# (7403, 2755)

# %%
X = torch.randn(size=(G.num_v, hyper["init_features_dim"]))
# X = torch.eye(hyper["init_features_dim"])
net = HGNNP(hyper["h_hyper_prmts"]).to(DEVICE)
hgnn_trainer = Trainer(net=net, X=X, hg=G, optimizer=None).to(DEVICE)
for (k,v) in hyper["l_hyper_prmts"].items():
    hgnn_trainer.layers.append(nn.BatchNorm1d(num_features=v["in_channels"]).to(DEVICE)) if v["use_bn"] else None
    hgnn_trainer.layers.append(nn.ReLU().to(DEVICE))
    if v["drop_rate"] > 0:
        hgnn_trainer.layers.append(nn.Dropout(v["drop_rate"]))
    hgnn_trainer.layers.append(nn.Linear(in_features=v["in_channels"],out_features=v["out_channels"],device=DEVICE))
hgnn_trainer.layers.append(nn.Softmax(dim=1))
# Out:
# ModuleList(
#   (0): HGNNP(
#     (layers): ModuleList(
#       (0): HGNNPConv(
#         (act): ReLU(inplace=True)
#         (drop): Dropout(p=0, inplace=False)
#         (theta): Linear(in_features=2048, out_features=1024, bias=True)
#       )
#       (1): HGNNPConv(
#         (act): ReLU(inplace=True)
#         (drop): Dropout(p=0, inplace=False)
#         (theta): Linear(in_features=1024, out_features=512, bias=True)
#       )
#       (2): HGNNPConv(
#         (act): ReLU(inplace=True)
#         (drop): Dropout(p=0, inplace=False)
#         (theta): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (3): HGNNPConv(
#         (act): ReLU(inplace=True)
#         (drop): Dropout(p=0, inplace=False)
#         (theta): Linear(in_features=256, out_features=128, bias=True)
#       )
#     )
#   )
#   (1): ReLU()
#   (2): Dropout(p=0.05, inplace=False)
#   (3): Linear(in_features=128, out_features=64, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.05, inplace=False)
#   (6): Linear(in_features=64, out_features=32, bias=True)
#   (7): ReLU()
#   (8): Dropout(p=0.05, inplace=False)
#   (9): Linear(in_features=32, out_features=16, bias=True)
#   (10): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): ReLU()
#   (12): Linear(in_features=16, out_features=3, bias=True)
#   (13): Softmax(dim=1)
# )

# %%
# hgnn_trainer.layers
# for n,p in hgnn_trainer.named_parameters():
#     print(n,p)
hgnn_trainer.weight = weight

# %%
temp_loss_total,temp_loss1,temp_loss2 = torch.zeros(1, requires_grad=False),torch.zeros(1, requires_grad=False),torch.zeros(1, requires_grad=False)
optim1 = optim.AdamW(hgnn_trainer.parameters(), lr=lr, weight_decay=5e-8)
hgnn_trainer.optimizer = optim1
for epoch in range(40000):
    if hgnn_trainer.weight >= 64000:
        hgnn_trainer.weight = hgnn_trainer.weight - sub
    elif hgnn_trainer.weight < 64000:
        hgnn_trainer.weight = hgnn_trainer.weight - (sub / 4)
    elif hgnn_trainer.weight < limit:
        hgnn_trainer.weight = limit
    loss,loss_1,loss_2 = hgnn_trainer.run(epoch=epoch)
    temp_loss_total += loss
    temp_loss1 += loss_1
    temp_loss2 += loss_2
    if epoch % 10 == 0:
        print(f"in {epoch} epoch, average loss: {temp_loss_total.item() / 10}")
        print(f"                , loss1: {temp_loss1.item() / 10}")
        print(f"                , loss2: {temp_loss2.item() / 10}")
        print(f"                , weight: {hgnn_trainer.weight}")
        print(f"=================================")
        sys.stdout.flush()
        temp_loss_total,temp_loss1,temp_loss2 = torch.zeros(1, requires_grad=False),torch.zeros(1, requires_grad=False),torch.zeros(1, requires_grad=False)
# Out:
# in 0 epoch, average loss: 55341299.2
#                 , loss1: 251.5678955078125
#                 , loss2: 1394.19755859375
#                 , weight: 219980
# =================================
# in 10 epoch, average loss: 553022566.4
#                 , loss1: 2515.1515625
#                 , loss2: 16180.828125
#                 , weight: 219780
# =================================
# in 20 epoch, average loss: 552499148.8
#                 , loss1: 2515.0427734375
#                 , loss2: 19617.4171875
#                 , weight: 219580
# =================================
# in 30 epoch, average loss: 551948083.2
#                 , loss1: 2514.805859375
#                 , loss2: 23608.6984375
#                 , weight: 219380
# =================================
# in 40 epoch, average loss: 551377408.0
#                 , loss1: 2514.475390625
#                 , loss2: 28323.628125
#                 , weight: 219180
# =================================
# in 50 epoch, average loss: 550790707.2
#                 , loss1: 2514.071875
#                 , loss2: 33042.85625
#                 , weight: 218980
# =================================
# in 60 epoch, average loss: 550181529.6
#                 , loss1: 2513.558203125
#                 , loss2: 38924.35
#                 , weight: 218780
# =================================
# in 70 epoch, average loss: 549380198.4
#                 , loss1: 2512.169140625
#                 , loss2: 44179.33125
#                 , weight: 218580
# =================================
# in 80 epoch, average loss: 548230860.8
#                 , loss1: 2509.196875
#                 , loss2: 46485.3875
#                 , weight: 218380
# =================================
# in 90 epoch, average loss: 546274969.6
#                 , loss1: 2502.544140625
#                 , loss2: 44522.3625
#                 , weight: 218180
# =================================
# in 100 epoch, average loss: 542711603.2
#                 , loss1: 2488.515625
#                 , loss2: 40646.1375
#                 , weight: 217980
# =================================
# in 110 epoch, average loss: 537878937.6
#                 , loss1: 2468.62109375
#                 , loss2: 40126.775
#                 , weight: 217780
# =================================
# in 120 epoch, average loss: 534190387.2
#                 , loss1: 2453.9556640625
#                 , loss2: 37688.9
#                 , weight: 217580
# =================================
# in 130 epoch, average loss: 531380377.6
#                 , loss1: 2443.3015625
#                 , loss2: 35475.203125
#                 , weight: 217380
# =================================
# in 140 epoch, average loss: 529050931.2
#                 , loss1: 2434.84609375
#                 , loss2: 31758.240625
#                 , weight: 217180
# =================================
# in 150 epoch, average loss: 525982054.4
#                 , loss1: 2422.9541015625
#                 , loss2: 31116.56875
#                 , weight: 216980
# =================================
# in 160 epoch, average loss: 522597273.6
#                 , loss1: 2409.55078125
#                 , loss2: 37843.728125
#                 , weight: 216780
# =================================
# in 170 epoch, average loss: 520095948.8
#                 , loss1: 2400.221484375
#                 , loss2: 39790.8625
#                 , weight: 216580
# =================================
# in 180 epoch, average loss: 518209996.8
#                 , loss1: 2393.7255859375
#                 , loss2: 40149.16875
#                 , weight: 216380
# =================================
# in 190 epoch, average loss: 516285849.6
#                 , loss1: 2387.0322265625
#                 , loss2: 42323.934375
#                 , weight: 216180
# =================================
# in 200 epoch, average loss: 514594099.2
#                 , loss1: 2381.4033203125
#                 , loss2: 44135.225
#                 , weight: 215980
# =================================
# in 210 epoch, average loss: 512878950.4
#                 , loss1: 2375.6630859375
#                 , loss2: 44495.825
#                 , weight: 215780
# =================================
# in 220 epoch, average loss: 511133798.4
#                 , loss1: 2369.7724609375
#                 , loss2: 44830.653125
#                 , weight: 215580
# =================================
# in 230 epoch, average loss: 509342412.8
#                 , loss1: 2363.651953125
#                 , loss2: 46257.940625
#                 , weight: 215380
# =================================
# in 240 epoch, average loss: 507550412.8
#                 , loss1: 2357.5119140625
#                 , loss2: 48767.615625
#                 , weight: 215180
# =================================
# in 250 epoch, average loss: 505632768.0
#                 , loss1: 2350.7791015625
#                 , loss2: 50611.35625
#                 , weight: 214980
# =================================
# in 260 epoch, average loss: 503523891.2
#                 , loss1: 2343.127734375
#                 , loss2: 55940.16875
#                 , weight: 214780
# =================================
# in 270 epoch, average loss: 501575372.8
#                 , loss1: 2336.2052734375
#                 , loss2: 62132.65
#                 , weight: 214580
# =================================
# in 280 epoch, average loss: 499821158.4
#                 , loss1: 2330.1654296875
#                 , loss2: 70530.7125
#                 , weight: 214380
# =================================
# in 290 epoch, average loss: 497946777.6
#                 , loss1: 2323.55859375
#                 , loss2: 77807.51875
#                 , weight: 214180
# =================================
# in 300 epoch, average loss: 495768934.4
#                 , loss1: 2315.5431640625
#                 , loss2: 80560.49375
#                 , weight: 213980
# =================================
# in 310 epoch, average loss: 493916569.6
#                 , loss1: 2309.0314453125
#                 , loss2: 83944.0375
#                 , weight: 213780
# =================================
# in 320 epoch, average loss: 492136345.6
#                 , loss1: 2302.8615234375
#                 , loss2: 83871.6125
#                 , weight: 213580
# =================================
# in 330 epoch, average loss: 490368768.0
#                 , loss1: 2296.7166015625
#                 , loss2: 88611.7625
#                 , weight: 213380
# =================================
# in 340 epoch, average loss: 488652902.4
#                 , loss1: 2290.8232421875
#                 , loss2: 88927.96875
#                 , weight: 213180
# =================================
# in 350 epoch, average loss: 486892800.0
#                 , loss1: 2284.687109375
#                 , loss2: 94461.96875
#                 , weight: 212980
# =================================
# in 360 epoch, average loss: 485302169.6
#                 , loss1: 2279.349609375
#                 , loss2: 96969.36875
#                 , weight: 212780
# =================================
# in 370 epoch, average loss: 483762739.2
#                 , loss1: 2274.233203125
#                 , loss2: 101458.70625
#                 , weight: 212580
# =================================
# in 380 epoch, average loss: 482093977.6
#                 , loss1: 2268.499609375
#                 , loss2: 105729.4125
#                 , weight: 212380
# =================================
# in 390 epoch, average loss: 480511590.4
#                 , loss1: 2263.163671875
#                 , loss2: 109804.3875
#                 , weight: 212180
# =================================
# in 400 epoch, average loss: 479085107.2
#                 , loss1: 2258.542578125
#                 , loss2: 115884.6625
#                 , weight: 211980
# =================================
# in 410 epoch, average loss: 477560166.4
#                 , loss1: 2253.4419921875
#                 , loss2: 123376.0625
#                 , weight: 211780
# =================================
# in 420 epoch, average loss: 476144640.0
#                 , loss1: 2248.8712890625
#                 , loss2: 125960.0625
#                 , weight: 211580
# =================================
# in 430 epoch, average loss: 474587801.6
#                 , loss1: 2243.602734375
#                 , loss2: 132991.1
#                 , weight: 211380
# =================================
# in 440 epoch, average loss: 473217024.0
#                 , loss1: 2239.2171875
#                 , loss2: 137495.7625
#                 , weight: 211180
# =================================
# in 450 epoch, average loss: 471607193.6
#                 , loss1: 2233.68203125
#                 , loss2: 143894.375
#                 , weight: 210980
# =================================
# in 460 epoch, average loss: 470306816.0
#                 , loss1: 2229.5916015625
#                 , loss2: 152792.5625
#                 , weight: 210780
# =================================
# in 470 epoch, average loss: 468750284.8
#                 , loss1: 2224.2861328125
#                 , loss2: 159826.875
#                 , weight: 210580
# =================================
# in 480 epoch, average loss: 467148953.6
#                 , loss1: 2218.755078125
#                 , loss2: 167480.1375
#                 , weight: 210380
# =================================
# in 490 epoch, average loss: 465671321.6
#                 , loss1: 2213.80625
#                 , loss2: 174174.65
#                 , weight: 210180
# =================================
# in 500 epoch, average loss: 463933030.4
#                 , loss1: 2207.614453125
#                 , loss2: 179290.3
#                 , weight: 209980
# =================================
# in 510 epoch, average loss: 462438297.6
#                 , loss1: 2202.5587890625
#                 , loss2: 187182.875
#                 , weight: 209780
# =================================
# in 520 epoch, average loss: 460782848.0
#                 , loss1: 2196.7544921875
#                 , loss2: 189213.8125
#                 , weight: 209580
# =================================
# in 530 epoch, average loss: 459381145.6
#                 , loss1: 2192.1177734375
#                 , loss2: 198187.3625
#                 , weight: 209380
# =================================
# in 540 epoch, average loss: 457805004.8
#                 , loss1: 2186.6552734375
#                 , loss2: 203513.675
#                 , weight: 209180
# =================================
# in 550 epoch, average loss: 456191436.8
#                 , loss1: 2181.006640625
#                 , loss2: 208307.825
#                 , weight: 208980
# =================================
# in 560 epoch, average loss: 454857369.6
#                 , loss1: 2176.666015625
#                 , loss2: 217117.875
#                 , weight: 208780
# =================================
# in 570 epoch, average loss: 453334988.8
#                 , loss1: 2171.411328125
#                 , loss2: 226514.325
#                 , weight: 208580
# =================================
# in 580 epoch, average loss: 451907276.8
#                 , loss1: 2166.637890625
#                 , loss2: 228255.5
#                 , weight: 208380
# =================================
# in 590 epoch, average loss: 450530099.2
#                 , loss1: 2162.0701171875
#                 , loss2: 235667.75
#                 , weight: 208180
# =================================
# in 600 epoch, average loss: 448971980.8
#                 , loss1: 2156.6205078125
#                 , loss2: 243838.55
#                 , weight: 207980
# =================================
# in 610 epoch, average loss: 447658649.6
#                 , loss1: 2152.342578125
#                 , loss2: 251087.525
#                 , weight: 207780
# =================================
# in 620 epoch, average loss: 446272409.6
#                 , loss1: 2147.708203125
#                 , loss2: 257847.175
#                 , weight: 207580
# =================================
# in 630 epoch, average loss: 444902707.2
#                 , loss1: 2143.1521484375
#                 , loss2: 262846.0
#                 , weight: 207380
# =================================
# in 640 epoch, average loss: 443472384.0
#                 , loss1: 2138.274609375
#                 , loss2: 272167.025
#                 , weight: 207180
# =================================
# in 650 epoch, average loss: 442423347.2
#                 , loss1: 2135.246484375
#                 , loss2: 277835.85
#                 , weight: 206980
# =================================
# in 660 epoch, average loss: 441097932.8
#                 , loss1: 2130.8654296875
#                 , loss2: 285724.45
#                 , weight: 206780
# =================================
# in 670 epoch, average loss: 439599513.6
#                 , loss1: 2125.6404296875
#                 , loss2: 293318.4
#                 , weight: 206580
# =================================
# in 680 epoch, average loss: 438307788.8
#                 , loss1: 2121.415625
#                 , loss2: 299039.35
#                 , weight: 206380
# =================================
# in 690 epoch, average loss: 437108224.0
#                 , loss1: 2117.605859375
#                 , loss2: 309614.25
#                 , weight: 206180
# =================================
# in 700 epoch, average loss: 435895603.2
#                 , loss1: 2113.752734375
#                 , loss2: 314517.05
#                 , weight: 205980
# =================================
# in 710 epoch, average loss: 434765107.2
#                 , loss1: 2110.277734375
#                 , loss2: 322239.4
#                 , weight: 205780
# =================================
# in 720 epoch, average loss: 433415475.2
#                 , loss1: 2105.735546875
#                 , loss2: 328748.65
#                 , weight: 205580
# =================================
# in 730 epoch, average loss: 432129792.0
#                 , loss1: 2101.496875
#                 , loss2: 335164.775
#                 , weight: 205380
# =================================
# in 740 epoch, average loss: 431011379.2
#                 , loss1: 2098.05859375
#                 , loss2: 342872.175
#                 , weight: 205180
# =================================
# in 750 epoch, average loss: 429855846.4
#                 , loss1: 2094.4361328125
#                 , loss2: 349818.45
#                 , weight: 204980
# =================================
# in 760 epoch, average loss: 428702873.6
#                 , loss1: 2090.8158203125
#                 , loss2: 357369.825
#                 , weight: 204780
# =================================
# in 770 epoch, average loss: 427658547.2
#                 , loss1: 2087.69609375
#                 , loss2: 369734.075
#                 , weight: 204580
# =================================
# in 780 epoch, average loss: 426497382.4
#                 , loss1: 2084.03359375
#                 , loss2: 375009.35
#                 , weight: 204380
# =================================
# in 790 epoch, average loss: 425238451.2
#                 , loss1: 2079.8935546875
#                 , loss2: 378603.875
#                 , weight: 204180
# =================================
# in 800 epoch, average loss: 424108262.4
#                 , loss1: 2076.3564453125
#                 , loss2: 386154.25
#                 , weight: 203980
# =================================
# in 810 epoch, average loss: 423003443.2
#                 , loss1: 2072.9048828125
#                 , loss2: 400260.225
#                 , weight: 203780
# =================================
# in 820 epoch, average loss: 421987020.8
#                 , loss1: 2069.9283203125
#                 , loss2: 404701.525
#                 , weight: 203580
# =================================
# in 830 epoch, average loss: 420577433.6
#                 , loss1: 2065.0005859375
#                 , loss2: 411724.6
#                 , weight: 203380
# =================================
# in 840 epoch, average loss: 419549824.0
#                 , loss1: 2061.9421875
#                 , loss2: 418786.15
#                 , weight: 203180
# =================================
# in 850 epoch, average loss: 418418534.4
#                 , loss1: 2058.36328125
#                 , loss2: 426632.4
#                 , weight: 202980
# =================================
# in 860 epoch, average loss: 417290342.4
#                 , loss1: 2054.796875
#                 , loss2: 433599.75
#                 , weight: 202780
# =================================
# in 870 epoch, average loss: 416189388.8
#                 , loss1: 2051.34453125
#                 , loss2: 443282.4
#                 , weight: 202580
# =================================
# in 880 epoch, average loss: 415161651.2
#                 , loss1: 2048.2275390625
#                 , loss2: 456975.1
#                 , weight: 202380
# =================================
# in 890 epoch, average loss: 414084249.6
#                 , loss1: 2044.9171875
#                 , loss2: 458789.55
#                 , weight: 202180
# =================================
# in 900 epoch, average loss: 413074867.2
#                 , loss1: 2041.8861328125
#                 , loss2: 470878.35
#                 , weight: 201980
# =================================
# in 910 epoch, average loss: 412062822.4
#                 , loss1: 2038.870703125
#                 , loss2: 475943.6
#                 , weight: 201780
# =================================
# in 920 epoch, average loss: 410738636.8
#                 , loss1: 2034.2734375
#                 , loss2: 486640.3
#                 , weight: 201580
# =================================
# in 930 epoch, average loss: 409864934.4
#                 , loss1: 2031.9197265625
#                 , loss2: 493999.25
#                 , weight: 201380
# =================================
# in 940 epoch, average loss: 408714828.8
#                 , loss1: 2028.1779296875
#                 , loss2: 503409.45
#                 , weight: 201180
# =================================
# in 950 epoch, average loss: 407837696.0
#                 , loss1: 2025.7931640625
#                 , loss2: 511437.75
#                 , weight: 200980
# =================================
# in 960 epoch, average loss: 406725555.2
#                 , loss1: 2022.213671875
#                 , loss2: 523428.4
#                 , weight: 200780
# =================================
# in 970 epoch, average loss: 405390617.6
#                 , loss1: 2017.5421875
#                 , loss2: 530332.9
#                 , weight: 200580
# =================================
# in 980 epoch, average loss: 404433510.4
#                 , loss1: 2014.7140625
#                 , loss2: 543685.2
#                 , weight: 200380
# =================================
# in 990 epoch, average loss: 403395891.2
#                 , loss1: 2011.4873046875
#                 , loss2: 555244.95
#                 , weight: 200180
# =================================
# in 1000 epoch, average loss: 402216934.4
#                 , loss1: 2007.5125
#                 , loss2: 573912.85
#                 , weight: 199980
# =================================
# in 1010 epoch, average loss: 401487411.2
#                 , loss1: 2005.8265625
#                 , loss2: 582955.65
#                 , weight: 199780
# =================================
# in 1020 epoch, average loss: 399914777.6
#                 , loss1: 1999.8931640625
#                 , loss2: 595943.7
#                 , weight: 199580
# =================================
# in 1030 epoch, average loss: 398727296.0
#                 , loss1: 1995.90703125
#                 , loss2: 603689.7
#                 , weight: 199380
# =================================
# in 1040 epoch, average loss: 397707238.4
#                 , loss1: 1992.771484375
#                 , loss2: 607561.6
#                 , weight: 199180
# =================================
# in 1050 epoch, average loss: 396488857.6
#                 , loss1: 1988.6072265625
#                 , loss2: 616730.0
#                 , weight: 198980
# =================================
# in 1060 epoch, average loss: 395626086.4
#                 , loss1: 1986.2546875
#                 , loss2: 619531.7
#                 , weight: 198780
# =================================
# in 1070 epoch, average loss: 394690278.4
#                 , loss1: 1983.41640625
#                 , loss2: 644860.9
#                 , weight: 198580
# =================================
# in 1080 epoch, average loss: 393575577.6
#                 , loss1: 1979.7767578125
#                 , loss2: 649210.7
#                 , weight: 198380
# =================================
# in 1090 epoch, average loss: 392532377.6
#                 , loss1: 1976.4845703125
#                 , loss2: 654701.3
#                 , weight: 198180
# =================================
# in 1100 epoch, average loss: 391297536.0
#                 , loss1: 1972.20625
#                 , loss2: 662548.1
#                 , weight: 197980
# =================================
# in 1110 epoch, average loss: 390085964.8
#                 , loss1: 1968.02734375
#                 , loss2: 672341.4
#                 , weight: 197780
# =================================
# in 1120 epoch, average loss: 389100313.6
#                 , loss1: 1964.991015625
#                 , loss2: 680523.05
#                 , weight: 197580
# =================================
# in 1130 epoch, average loss: 388087859.2
#                 , loss1: 1961.7638671875
#                 , loss2: 698338.5
#                 , weight: 197380
# =================================
# in 1140 epoch, average loss: 387248972.8
#                 , loss1: 1959.4794921875
#                 , loss2: 702347.95
#                 , weight: 197180
# =================================
# in 1150 epoch, average loss: 386039116.8
#                 , loss1: 1955.2982421875
#                 , loss2: 708396.3
#                 , weight: 196980
# =================================
# in 1160 epoch, average loss: 385098214.4
#                 , loss1: 1952.443359375
#                 , loss2: 720638.75
#                 , weight: 196780
# =================================
# in 1170 epoch, average loss: 383806387.2
#                 , loss1: 1947.8810546875
#                 , loss2: 716568.75
#                 , weight: 196580
# =================================
# in 1180 epoch, average loss: 383273267.2
#                 , loss1: 1946.98125
#                 , loss2: 749856.2
#                 , weight: 196380
# =================================
# in 1190 epoch, average loss: 381875532.8
#                 , loss1: 1941.864453125
#                 , loss2: 745708.9
#                 , weight: 196180
# =================================
# in 1200 epoch, average loss: 380955622.4
#                 , loss1: 1939.0767578125
#                 , loss2: 760713.25
#                 , weight: 195980
# =================================
# in 1210 epoch, average loss: 379770624.0
#                 , loss1: 1935.001171875
#                 , loss2: 761868.1
#                 , weight: 195780
# =================================
# in 1220 epoch, average loss: 378819840.0
#                 , loss1: 1932.0556640625
#                 , loss2: 774471.0
#                 , weight: 195580
# =================================
# in 1230 epoch, average loss: 377786188.8
#                 , loss1: 1928.6654296875
#                 , loss2: 789861.0
#                 , weight: 195380
# =================================
# in 1240 epoch, average loss: 376771558.4
#                 , loss1: 1925.37265625
#                 , loss2: 803909.15
#                 , weight: 195180
# =================================
# in 1250 epoch, average loss: 375523686.4
#                 , loss1: 1920.9396484375
#                 , loss2: 805897.7
#                 , weight: 194980
# =================================
# in 1260 epoch, average loss: 374717081.6
#                 , loss1: 1918.7703125
#                 , loss2: 806249.6
#                 , weight: 194780
# =================================
# in 1270 epoch, average loss: 373599232.0
#                 , loss1: 1914.898046875
#                 , loss2: 826033.8
#                 , weight: 194580
# =================================
# in 1280 epoch, average loss: 372508134.4
#                 , loss1: 1911.236328125
#                 , loss2: 829989.8
#                 , weight: 194380
# =================================
# in 1290 epoch, average loss: 371959526.4
#                 , loss1: 1910.240234375
#                 , loss2: 857103.9
#                 , weight: 194180
# =================================
# in 1300 epoch, average loss: 372040806.4
#                 , loss1: 1912.5015625
#                 , loss2: 881649.0
#                 , weight: 193980
# =================================
# in 1310 epoch, average loss: 373793996.8
#                 , loss1: 1923.085546875
#                 , loss2: 964908.1
#                 , weight: 193780
# =================================
# in 1320 epoch, average loss: 369440076.8
#                 , loss1: 1902.8994140625
#                 , loss2: 905430.5
#                 , weight: 193580
# =================================
# in 1330 epoch, average loss: 367964569.6
#                 , loss1: 1897.373828125
#                 , loss2: 879591.6
#                 , weight: 193380
# =================================
# in 1340 epoch, average loss: 366712755.2
#                 , loss1: 1892.8376953125
#                 , loss2: 883934.2
#                 , weight: 193180
# =================================
# in 1350 epoch, average loss: 365630028.8
#                 , loss1: 1889.164453125
#                 , loss2: 889018.3
#                 , weight: 192980
# =================================
# in 1360 epoch, average loss: 364602880.0
#                 , loss1: 1885.7369140625
#                 , loss2: 900713.1
#                 , weight: 192780
# =================================
# in 1370 epoch, average loss: 363444044.8
#                 , loss1: 1881.634765625
#                 , loss2: 909421.6
#                 , weight: 192580
# =================================
# in 1380 epoch, average loss: 362648883.2
#                 , loss1: 1879.45546875
#                 , loss2: 909984.1
#                 , weight: 192380
# =================================
# in 1390 epoch, average loss: 361841331.2
#                 , loss1: 1877.099609375
#                 , loss2: 931385.7
#                 , weight: 192180
# =================================
# in 1400 epoch, average loss: 360739507.2
#                 , loss1: 1873.3587890625
#                 , loss2: 923423.0
#                 , weight: 191980
# =================================
# in 1410 epoch, average loss: 359777382.4
#                 , loss1: 1870.2259765625
#                 , loss2: 937115.4
#                 , weight: 191780
# =================================
# in 1420 epoch, average loss: 358878540.8
#                 , loss1: 1867.457421875
#                 , loss2: 942871.2
#                 , weight: 191580
# =================================
# in 1430 epoch, average loss: 357879603.2
#                 , loss1: 1864.1626953125
#                 , loss2: 948316.2
#                 , weight: 191380
# =================================
# in 1440 epoch, average loss: 357010483.2
#                 , loss1: 1861.5498046875
#                 , loss2: 951791.5
#                 , weight: 191180
# =================================
# in 1450 epoch, average loss: 356279731.2
#                 , loss1: 1859.584375
#                 , loss2: 968830.4
#                 , weight: 190980
# =================================
# in 1460 epoch, average loss: 355616153.6
#                 , loss1: 1858.051953125
#                 , loss2: 969756.0
#                 , weight: 190780
# =================================
# in 1470 epoch, average loss: 354498816.0
#                 , loss1: 1854.09296875
#                 , loss2: 978835.6
#                 , weight: 190580
# =================================
# in 1480 epoch, average loss: 353863244.8
#                 , loss1: 1852.626953125
#                 , loss2: 993325.3
#                 , weight: 190380
# =================================
# in 1490 epoch, average loss: 352924928.0
#                 , loss1: 1849.62890625
#                 , loss2: 996081.6
#                 , weight: 190180
# =================================
# in 1500 epoch, average loss: 356041190.4
#                 , loss1: 1867.24375
#                 , loss2: 1134615.4
#                 , weight: 189980
# =================================
# in 1510 epoch, average loss: 353006668.8
#                 , loss1: 1853.4859375
#                 , loss2: 1085071.5
#                 , weight: 189780
# =================================
# in 1520 epoch, average loss: 351376537.6
#                 , loss1: 1847.0373046875
#                 , loss2: 1048804.9
#                 , weight: 189580
# =================================
# in 1530 epoch, average loss: 349607219.2
#                 , loss1: 1839.7408203125
#                 , loss2: 1031453.1
#                 , weight: 189380
# =================================
# in 1540 epoch, average loss: 348527104.0
#                 , loss1: 1835.98515625
#                 , loss2: 1030080.0
#                 , weight: 189180
# =================================
# in 1550 epoch, average loss: 347474201.6
#                 , loss1: 1832.348046875
#                 , loss2: 1032103.3
#                 , weight: 188980
# =================================
# in 1560 epoch, average loss: 346708172.8
#                 , loss1: 1830.2162109375
#                 , loss2: 1035189.5
#                 , weight: 188780
# =================================
# in 1570 epoch, average loss: 346967219.2
#                 , loss1: 1833.2353515625
#                 , loss2: 1090776.0
#                 , weight: 188580
# =================================
# in 1580 epoch, average loss: 345324569.6
#                 , loss1: 1826.6287109375
#                 , loss2: 1059723.2
#                 , weight: 188380
# =================================
# in 1590 epoch, average loss: 344219289.6
#                 , loss1: 1822.71875
#                 , loss2: 1055938.6
#                 , weight: 188180
# =================================
# in 1600 epoch, average loss: 343322777.6
#                 , loss1: 1819.886328125
#                 , loss2: 1056699.9
#                 , weight: 187980
# =================================
# in 1610 epoch, average loss: 343424051.2
#                 , loss1: 1822.219921875
#                 , loss2: 1083716.0
#                 , weight: 187780
# =================================
# in 1620 epoch, average loss: 342367590.4
#                 , loss1: 1818.395703125
#                 , loss2: 1109045.7
#                 , weight: 187580
# =================================
# in 1630 epoch, average loss: 340976768.0
#                 , loss1: 1813.040625
#                 , loss2: 1085955.2
#                 , weight: 187380
# =================================
# in 1640 epoch, average loss: 340077312.0
#                 , loss1: 1810.192578125
#                 , loss2: 1082553.2
#                 , weight: 187180
# =================================
# in 1650 epoch, average loss: 339083136.0
#                 , loss1: 1806.7994140625
#                 , loss2: 1085205.3
#                 , weight: 186980
# =================================
# in 1660 epoch, average loss: 338503910.4
#                 , loss1: 1805.62421875
#                 , loss2: 1086917.4
#                 , weight: 186780
# =================================
# in 1670 epoch, average loss: 337690956.8
#                 , loss1: 1803.1142578125
#                 , loss2: 1103537.9
#                 , weight: 186580
# =================================
# in 1680 epoch, average loss: 336924313.6
#                 , loss1: 1800.96171875
#                 , loss2: 1098978.2
#                 , weight: 186380
# =================================
# in 1690 epoch, average loss: 336289484.8
#                 , loss1: 1799.3845703125
#                 , loss2: 1118119.0
#                 , weight: 186180
# =================================
# in 1700 epoch, average loss: 335513753.6
#                 , loss1: 1797.1970703125
#                 , loss2: 1109288.5
#                 , weight: 185980
# =================================
# in 1710 epoch, average loss: 334666291.2
#                 , loss1: 1794.527734375
#                 , loss2: 1117402.6
#                 , weight: 185780
# =================================
# in 1720 epoch, average loss: 333972121.6
#                 , loss1: 1792.696484375
#                 , loss2: 1122142.7
#                 , weight: 185580
# =================================
# in 1730 epoch, average loss: 334924953.6
#                 , loss1: 1799.2890625
#                 , loss2: 1211227.8
#                 , weight: 185380
# =================================
# in 1740 epoch, average loss: 339584716.8
#                 , loss1: 1824.7916015625
#                 , loss2: 1505860.4
#                 , weight: 185180
# =================================
# in 1750 epoch, average loss: 336640716.8
#                 , loss1: 1811.73203125
#                 , loss2: 1342838.0
#                 , weight: 184980
# =================================
# in 1760 epoch, average loss: 333037516.8
#                 , loss1: 1794.736328125
#                 , loss2: 1244492.0
#                 , weight: 184780
# =================================
# in 1770 epoch, average loss: 331156300.8
#                 , loss1: 1786.7189453125
#                 , loss2: 1202798.8
#                 , weight: 184580
# =================================
# in 1780 epoch, average loss: 330081612.8
#                 , loss1: 1782.95234375
#                 , loss2: 1180268.8
#                 , weight: 184380
# =================================
# in 1790 epoch, average loss: 329102540.8
#                 , loss1: 1779.5125
#                 , loss2: 1191678.5
#                 , weight: 184180
# =================================
# in 1800 epoch, average loss: 328242380.8
#                 , loss1: 1776.7646484375
#                 , loss2: 1193274.4
#                 , weight: 183980
# =================================
# in 1810 epoch, average loss: 327446758.4
#                 , loss1: 1774.2505859375
#                 , loss2: 1215254.2
#                 , weight: 183780
# =================================
# in 1820 epoch, average loss: 326686822.4
#                 , loss1: 1771.93203125
#                 , loss2: 1236083.3
#                 , weight: 183580
# =================================
# in 1830 epoch, average loss: 325556582.4
#                 , loss1: 1767.6228515625
#                 , loss2: 1250785.8
#                 , weight: 183380
# =================================
# in 1840 epoch, average loss: 324825958.4
#                 , loss1: 1765.5375
#                 , loss2: 1255846.6
#                 , weight: 183180
# =================================
# in 1850 epoch, average loss: 323959552.0
#                 , loss1: 1762.6578125
#                 , loss2: 1269756.8
#                 , weight: 182980
# =================================
# in 1860 epoch, average loss: 323226316.8
#                 , loss1: 1760.5376953125
#                 , loss2: 1276704.0
#                 , weight: 182780
# =================================
# in 1870 epoch, average loss: 322340710.4
#                 , loss1: 1757.521875
#                 , loss2: 1294129.2
#                 , weight: 182580
# =================================
# in 1880 epoch, average loss: 321434470.4
#                 , loss1: 1754.519140625
#                 , loss2: 1287338.3
#                 , weight: 182380
# =================================
# in 1890 epoch, average loss: 320623718.4
#                 , loss1: 1751.9259765625
#                 , loss2: 1300117.7
#                 , weight: 182180
# =================================
# in 1900 epoch, average loss: 319872512.0
#                 , loss1: 1749.7076171875
#                 , loss2: 1303186.3
#                 , weight: 181980
# =================================
# in 1910 epoch, average loss: 319123302.4
#                 , loss1: 1747.479296875
#                 , loss2: 1309212.0
#                 , weight: 181780
# =================================
# in 1920 epoch, average loss: 318345932.8
#                 , loss1: 1745.0759765625
#                 , loss2: 1317957.5
#                 , weight: 181580
# =================================
# in 1930 epoch, average loss: 317649305.6
#                 , loss1: 1743.1384765625
#                 , loss2: 1321959.7
#                 , weight: 181380
# =================================
# in 1940 epoch, average loss: 316880179.2
#                 , loss1: 1740.7599609375
#                 , loss2: 1332587.1
#                 , weight: 181180
# =================================
# in 1950 epoch, average loss: 316479436.8
#                 , loss1: 1740.4275390625
#                 , loss2: 1340230.6
#                 , weight: 180980
# =================================
# in 1960 epoch, average loss: 315666073.6
#                 , loss1: 1737.855078125
#                 , loss2: 1340191.7
#                 , weight: 180780
# =================================
# in 1970 epoch, average loss: 315033369.6
#                 , loss1: 1736.2443359375
#                 , loss2: 1346054.0
#                 , weight: 180580
# =================================
# in 1980 epoch, average loss: 314668672.0
#                 , loss1: 1735.9345703125
#                 , loss2: 1384618.4
#                 , weight: 180380
# =================================
# in 1990 epoch, average loss: 317476812.8
#                 , loss1: 1752.41171875
#                 , loss2: 1570216.7
#                 , weight: 180180
# =================================
# in 2000 epoch, average loss: 320290944.0
#                 , loss1: 1769.19140625
#                 , loss2: 1712160.2
#                 , weight: 179980
# =================================
# in 2010 epoch, average loss: 315274726.4
#                 , loss1: 1744.3927734375
#                 , loss2: 1510659.5
#                 , weight: 179780
# =================================
# in 2020 epoch, average loss: 312786816.0
#                 , loss1: 1732.980859375
#                 , loss2: 1421985.1
#                 , weight: 179580
# =================================
# in 2030 epoch, average loss: 311643136.0
#                 , loss1: 1728.6162109375
#                 , loss2: 1408347.0
#                 , weight: 179380
# =================================
# in 2040 epoch, average loss: 310680217.6
#                 , loss1: 1725.2166015625
#                 , loss2: 1400569.4
#                 , weight: 179180
# =================================
# in 2050 epoch, average loss: 309647411.2
#                 , loss1: 1721.4228515625
#                 , loss2: 1392214.7
#                 , weight: 178980
# =================================
# in 2060 epoch, average loss: 308871628.8
#                 , loss1: 1718.975390625
#                 , loss2: 1398455.8
#                 , weight: 178780
# =================================
# in 2070 epoch, average loss: 308305664.0
#                 , loss1: 1717.626953125
#                 , loss2: 1417221.6
#                 , weight: 178580
# =================================
# in 2080 epoch, average loss: 307438208.0
#                 , loss1: 1714.707421875
#                 , loss2: 1414349.8
#                 , weight: 178380
# =================================
# in 2090 epoch, average loss: 306766233.6
#                 , loss1: 1712.8638671875
#                 , loss2: 1413991.4
#                 , weight: 178180
# =================================
# in 2100 epoch, average loss: 306151936.0
#                 , loss1: 1711.27421875
#                 , loss2: 1425351.9
#                 , weight: 177980
# =================================
# in 2110 epoch, average loss: 305439641.6
#                 , loss1: 1709.170703125
#                 , loss2: 1429384.0
#                 , weight: 177780
# =================================
# in 2120 epoch, average loss: 305710105.6
#                 , loss1: 1712.4787109375
#                 , loss2: 1454253.2
#                 , weight: 177580
# =================================
# in 2130 epoch, average loss: 310391424.0
#                 , loss1: 1738.7064453125
#                 , loss2: 1823720.8
#                 , weight: 177380
# =================================
# in 2140 epoch, average loss: 306579814.4
#                 , loss1: 1720.1595703125
#                 , loss2: 1646938.4
#                 , weight: 177180
# =================================
# in 2150 epoch, average loss: 304102963.2
#                 , loss1: 1708.66484375
#                 , loss2: 1549511.0
#                 , weight: 176980
# =================================
# in 2160 epoch, average loss: 302891520.0
#                 , loss1: 1704.0470703125
#                 , loss2: 1496632.6
#                 , weight: 176780
# =================================
# in 2170 epoch, average loss: 301747763.2
#                 , loss1: 1699.5611328125
#                 , loss2: 1486269.6
#                 , weight: 176580
# =================================
# in 2180 epoch, average loss: 300913996.8
#                 , loss1: 1696.7779296875
#                 , loss2: 1483542.6
#                 , weight: 176380
# =================================
# in 2190 epoch, average loss: 300106112.0
#                 , loss1: 1694.0349609375
#                 , loss2: 1498563.5
#                 , weight: 176180
# =================================
# in 2200 epoch, average loss: 299325286.4
#                 , loss1: 1691.42578125
#                 , loss2: 1515921.7
#                 , weight: 175980
# =================================
# in 2210 epoch, average loss: 298751488.0
#                 , loss1: 1690.086328125
#                 , loss2: 1515954.6
#                 , weight: 175780
# =================================
# in 2220 epoch, average loss: 297971148.8
#                 , loss1: 1687.5244140625
#                 , loss2: 1523769.6
#                 , weight: 175580
# =================================
# in 2230 epoch, average loss: 297368038.4
#                 , loss1: 1685.9685546875
#                 , loss2: 1531090.0
#                 , weight: 175380
# =================================
# in 2240 epoch, average loss: 296624204.8
#                 , loss1: 1683.5939453125
#                 , loss2: 1540701.4
#                 , weight: 175180
# =================================
# in 2250 epoch, average loss: 296100864.0
#                 , loss1: 1682.5517578125
#                 , loss2: 1536503.4
#                 , weight: 174980
# =================================
# in 2260 epoch, average loss: 296060467.2
#                 , loss1: 1683.914453125
#                 , loss2: 1594491.0
#                 , weight: 174780
# =================================
# in 2270 epoch, average loss: 295521126.4
#                 , loss1: 1682.644921875
#                 , loss2: 1613370.8
#                 , weight: 174580
# =================================
# in 2280 epoch, average loss: 294540160.0
#                 , loss1: 1679.100390625
#                 , loss2: 1587425.6
#                 , weight: 174380
# =================================
# in 2290 epoch, average loss: 293775360.0
#                 , loss1: 1676.61484375
#                 , loss2: 1591591.9
#                 , weight: 174180
# =================================
# in 2300 epoch, average loss: 292872294.4
#                 , loss1: 1673.3884765625
#                 , loss2: 1585511.8
#                 , weight: 173980
# =================================
# in 2310 epoch, average loss: 292228480.0
#                 , loss1: 1671.5052734375
#                 , loss2: 1603816.2
#                 , weight: 173780
# =================================
# in 2320 epoch, average loss: 291518003.2
#                 , loss1: 1669.336328125
#                 , loss2: 1604291.4
#                 , weight: 173580
# =================================
# in 2330 epoch, average loss: 290773606.4
#                 , loss1: 1666.9318359375
#                 , loss2: 1610906.3
#                 , weight: 173380
# =================================
# in 2340 epoch, average loss: 290189875.2
#                 , loss1: 1665.389453125
#                 , loss2: 1627810.3
#                 , weight: 173180
# =================================
# in 2350 epoch, average loss: 289640448.0
#                 , loss1: 1664.1197265625
#                 , loss2: 1631184.2
#                 , weight: 172980
# =================================
# in 2360 epoch, average loss: 288894924.8
#                 , loss1: 1661.64609375
#                 , loss2: 1646150.5
#                 , weight: 172780
# =================================
# in 2370 epoch, average loss: 288550835.2
#                 , loss1: 1661.5130859375
#                 , loss2: 1657341.4
#                 , weight: 172580
# =================================
# in 2380 epoch, average loss: 287886515.2
#                 , loss1: 1659.584375
#                 , loss2: 1657917.2
#                 , weight: 172380
# =================================
# in 2390 epoch, average loss: 287229056.0
#                 , loss1: 1657.53828125
#                 , loss2: 1684944.6
#                 , weight: 172180
# =================================
# in 2400 epoch, average loss: 286379443.2
#                 , loss1: 1654.63515625
#                 , loss2: 1666316.8
#                 , weight: 171980
# =================================
# in 2410 epoch, average loss: 285595443.2
#                 , loss1: 1651.98359375
#                 , loss2: 1669025.0
#                 , weight: 171780
# =================================
# in 2420 epoch, average loss: 285102156.8
#                 , loss1: 1650.94296875
#                 , loss2: 1684768.6
#                 , weight: 171580
# =================================
# in 2430 epoch, average loss: 284896614.4
#                 , loss1: 1651.5634765625
#                 , loss2: 1703038.8
#                 , weight: 171380
# =================================
# in 2440 epoch, average loss: 283909350.4
#                 , loss1: 1647.788671875
#                 , loss2: 1692510.4
#                 , weight: 171180
# =================================
# in 2450 epoch, average loss: 283387468.8
#                 , loss1: 1646.62265625
#                 , loss2: 1699664.8
#                 , weight: 170980
# =================================
# in 2460 epoch, average loss: 282759168.0
#                 , loss1: 1644.8421875
#                 , loss2: 1704883.4
#                 , weight: 170780
# =================================
# in 2470 epoch, average loss: 282074496.0
#                 , loss1: 1642.7916015625
#                 , loss2: 1699236.8
#                 , weight: 170580
# =================================
# in 2480 epoch, average loss: 281607424.0
#                 , loss1: 1641.9275390625
#                 , loss2: 1708035.4
#                 , weight: 170380
# =================================
# in 2490 epoch, average loss: 281381555.2
#                 , loss1: 1642.351953125
#                 , loss2: 1738228.4
#                 , weight: 170180
# =================================
# in 2500 epoch, average loss: 280463641.6
#                 , loss1: 1638.973828125
#                 , loss2: 1723304.4
#                 , weight: 169980
# =================================
# in 2510 epoch, average loss: 280393881.6
#                 , loss1: 1640.3515625
#                 , loss2: 1747446.6
#                 , weight: 169780
# =================================
# in 2520 epoch, average loss: 284132275.2
#                 , loss1: 1662.201171875
#                 , loss2: 2106860.6
#                 , weight: 169580
# =================================
# in 2530 epoch, average loss: 287653017.6
#                 , loss1: 1684.63671875
#                 , loss2: 2158049.0
#                 , weight: 169380
# =================================
# in 2540 epoch, average loss: 283578214.4
#                 , loss1: 1663.054296875
#                 , loss2: 2072479.8
#                 , weight: 169180
# =================================
# in 2550 epoch, average loss: 279978726.4
#                 , loss1: 1644.5443359375
#                 , loss2: 1935525.0
#                 , weight: 168980
# =================================
# in 2560 epoch, average loss: 278026368.0
#                 , loss1: 1635.45234375
#                 , loss2: 1847454.8
#                 , weight: 168780
# =================================
# in 2570 epoch, average loss: 276905472.0
#                 , loss1: 1631.2060546875
#                 , loss2: 1769949.2
#                 , weight: 168580
# =================================
# in 2580 epoch, average loss: 276155801.6
#                 , loss1: 1628.71806640625
#                 , loss2: 1765624.4
#                 , weight: 168380
# =================================
# in 2590 epoch, average loss: 275558297.6
#                 , loss1: 1627.0712890625
#                 , loss2: 1770964.0
#                 , weight: 168180
# =================================
# in 2600 epoch, average loss: 275031577.6
#                 , loss1: 1625.815625
#                 , loss2: 1780731.2
#                 , weight: 167980
# =================================
# in 2610 epoch, average loss: 274402585.6
#                 , loss1: 1624.05107421875
#                 , loss2: 1773131.4
#                 , weight: 167780
# =================================
# in 2620 epoch, average loss: 274162892.8
#                 , loss1: 1624.3263671875
#                 , loss2: 1812134.8
# ...
# in 25510 epoch, average loss: -63497894.4
#                 , loss1: 2587.708984375
#                 , loss2: 23894.253125
#                 , weight: -24570.0
# =================================
# in 25520 epoch, average loss: -64378886.4
#                 , loss1: 2618.4220703125
#                 , loss2: 27786.9375
#                 , weight: -24620.0
# =================================
# in 25530 epoch, average loss: -64576563.2
#                 , loss1: 2620.380859375
#                 , loss2: 9277.91640625
#                 , weight: -24670.0
# =================================
# in 25540 epoch, average loss: -64801811.2
#                 , loss1: 2624.1453125
#                 , loss2: 8038.31875
#                 , weight: -24720.0
# =================================
# in 25550 epoch, average loss: -64948230.4
#                 , loss1: 2624.7859375
#                 , loss2: 8659.09609375
#                 , weight: -24770.0
# =================================
# in 25560 epoch, average loss: -65121536.0
#                 , loss1: 2626.5671875
#                 , loss2: 10739.35859375
#                 , weight: -24820.0
# =================================
# in 25570 epoch, average loss: -65247872.0
#                 , loss1: 2626.2875
#                 , loss2: 8826.5734375
#                 , weight: -24870.0
# =================================
# in 25580 epoch, average loss: -65416704.0
#                 , loss1: 2627.81640625
#                 , loss2: 9376.4984375
#                 , weight: -24920.0
# =================================
# in 25590 epoch, average loss: -65521209.6
#                 , loss1: 2626.6837890625
#                 , loss2: 7952.76953125
#                 , weight: -24970.0
# =================================
# in 25600 epoch, average loss: -65445907.2
#                 , loss1: 2618.61171875
#                 , loss2: 12802.9515625
#                 , weight: -25020.0
# =================================
# in 25610 epoch, average loss: -65615366.4
#                 , loss1: 2620.1177734375
#                 , loss2: 12077.81484375
#                 , weight: -25070.0
# =================================
# in 25620 epoch, average loss: -65557753.6
#                 , loss1: 2612.6130859375
#                 , loss2: 12372.340625
#                 , weight: -25120.0
# =================================
# in 25630 epoch, average loss: -65970873.6
#                 , loss1: 2623.962890625
#                 , loss2: 15262.7234375
#                 , weight: -25170.0
# =================================
# in 25640 epoch, average loss: -66087129.6
#                 , loss1: 2623.048828125
#                 , loss2: 7163.91015625
#                 , weight: -25220.0
# =================================
# in 25650 epoch, average loss: -66286118.4
#                 , loss1: 2625.8453125
#                 , loss2: 9918.29296875
#                 , weight: -25270.0
# =================================
# in 25660 epoch, average loss: -66423398.4
#                 , loss1: 2625.9400390625
#                 , loss2: 6341.01171875
#                 , weight: -25320.0
# =================================
# in 25670 epoch, average loss: -66638080.0
#                 , loss1: 2629.314453125
#                 , loss2: 8486.615625
#                 , weight: -25370.0
# =================================
# in 25680 epoch, average loss: -66714860.8
#                 , loss1: 2627.2271484375
#                 , loss2: 10120.0484375
#                 , weight: -25420.0
# =================================
# in 25690 epoch, average loss: -66767500.8
#                 , loss1: 2624.075
#                 , loss2: 8570.503125
#                 , weight: -25470.0
# =================================
# in 25700 epoch, average loss: -66845369.6
#                 , loss1: 2622.149609375
#                 , loss2: 12987.928125
#                 , weight: -25520.0
# =================================
# in 25710 epoch, average loss: -67045542.4
#                 , loss1: 2624.6986328125
#                 , loss2: 8939.09140625
#                 , weight: -25570.0
# =================================
# in 25720 epoch, average loss: -66997196.8
#                 , loss1: 2617.8248046875
#                 , loss2: 12559.6609375
#                 , weight: -25620.0
# =================================
# in 25730 epoch, average loss: -67361107.2
#                 , loss1: 2627.0890625
#                 , loss2: 17197.04375
#                 , weight: -25670.0
# =================================
# in 25740 epoch, average loss: -67415180.8
#                 , loss1: 2623.7568359375
#                 , loss2: 8808.88828125
#                 , weight: -25720.0
# =================================
# in 25750 epoch, average loss: -67554649.6
#                 , loss1: 2624.171875
#                 , loss2: 11176.196875
#                 , weight: -25770.0
# =================================
# in 25760 epoch, average loss: -67704012.8
#                 , loss1: 2625.08671875
#                 , loss2: 16655.4546875
#                 , weight: -25820.0
# =================================
# in 25770 epoch, average loss: -67816396.8
#                 , loss1: 2624.121484375
#                 , loss2: 10592.915625
#                 , weight: -25870.0
# =================================
# in 25780 epoch, average loss: -67935302.4
#                 , loss1: 2623.6552734375
#                 , loss2: 10833.1890625
#                 , weight: -25920.0
# =================================
# in 25790 epoch, average loss: -68239302.4
#                 , loss1: 2630.2478515625
#                 , loss2: 9048.60546875
#                 , weight: -25970.0
# =================================
# in 25800 epoch, average loss: -68324921.6
#                 , loss1: 2628.6212890625
#                 , loss2: 12654.5265625
#                 , weight: -26020.0
# =================================
# in 25810 epoch, average loss: -68108384.0
#                 , loss1: 2615.246875
#                 , loss2: 12193.95390625
#                 , weight: -26070.0
# =================================
# in 25820 epoch, average loss: -68312332.8
#                 , loss1: 2618.1916015625
#                 , loss2: 15865.259375
#                 , weight: -26120.0
# =================================
# in 25830 epoch, average loss: -68146694.4
#                 , loss1: 2606.9455078125
#                 , loss2: 18494.29375
#                 , weight: -26170.0
# =================================
# in 25840 epoch, average loss: -68751763.2
#                 , loss1: 2624.784375
#                 , loss2: 11028.6703125
#                 , weight: -26220.0
# =================================
# in 25850 epoch, average loss: -68909721.6
#                 , loss1: 2625.73671875
#                 , loss2: 9307.18359375
#                 , weight: -26270.0
# =================================
# in 25860 epoch, average loss: -68926368.0
#                 , loss1: 2621.6814453125
#                 , loss2: 17291.1265625
#                 , weight: -26320.0
# =================================
# in 25870 epoch, average loss: -69205184.0
#                 , loss1: 2626.9255859375
#                 , loss2: 7757.3609375
#                 , weight: -26370.0
# =================================
# in 25880 epoch, average loss: -69337612.8
#                 , loss1: 2626.94765625
#                 , loss2: 7242.02890625
#                 , weight: -26420.0
# =================================
# in 25890 epoch, average loss: -69473593.6
#                 , loss1: 2627.2654296875
#                 , loss2: 10994.82265625
#                 , weight: -26470.0
# =================================
# in 25900 epoch, average loss: -69608985.6
#                 , loss1: 2627.490625
#                 , loss2: 12946.53046875
#                 , weight: -26520.0
# =================================
# in 25910 epoch, average loss: -69737228.8
#                 , loss1: 2627.199609375
#                 , loss2: 8336.3859375
#                 , weight: -26570.0
# =================================
# in 25920 epoch, average loss: -69813401.6
#                 , loss1: 2625.170703125
#                 , loss2: 9555.1625
#                 , weight: -26620.0
# =================================
# in 25930 epoch, average loss: -70055392.0
#                 , loss1: 2629.424609375
#                 , loss2: 12208.79765625
#                 , weight: -26670.0
# =================================
# in 25940 epoch, average loss: -70225747.2
#                 , loss1: 2630.755859375
#                 , loss2: 8861.86953125
#                 , weight: -26720.0
# =================================
# in 25950 epoch, average loss: -70404544.0
#                 , loss1: 2632.5392578125
#                 , loss2: 9278.18203125
#                 , weight: -26770.0
# =================================
# in 25960 epoch, average loss: -70525100.8
#                 , loss1: 2632.087890625
#                 , loss2: 8278.54140625
#                 , weight: -26820.0
# =================================
# in 25970 epoch, average loss: -70570041.6
#                 , loss1: 2628.8203125
#                 , loss2: 7199.10234375
#                 , weight: -26870.0
# =================================
# in 25980 epoch, average loss: -70610854.4
#                 , loss1: 2625.7044921875
#                 , loss2: 13970.7046875
#                 , weight: -26920.0
# =================================
# in 25990 epoch, average loss: -70349574.4
#                 , loss1: 2611.1279296875
#                 , loss2: 14012.05
#                 , weight: -26970.0
# =================================
# in 26000 epoch, average loss: -71032640.0
#                 , loss1: 2631.7322265625
#                 , loss2: 17554.5171875
#                 , weight: -27020.0
# =================================
# in 26010 epoch, average loss: -71148876.8
#                 , loss1: 2630.8576171875
#                 , loss2: 9249.36171875
#                 , weight: -27070.0
# =================================
# in 26020 epoch, average loss: -71244070.4
#                 , loss1: 2629.44765625
#                 , loss2: 7375.37890625
#                 , weight: -27120.0
# =================================
# in 26030 epoch, average loss: -71467436.8
#                 , loss1: 2632.866796875
#                 , loss2: 8312.175
#                 , weight: -27170.0
# =================================
# in 26040 epoch, average loss: -71523353.6
#                 , loss1: 2630.1771484375
#                 , loss2: 10909.434375
#                 , weight: -27220.0
# =================================
# in 26050 epoch, average loss: -71653222.4
#                 , loss1: 2630.0728515625
#                 , loss2: 9698.30078125
#                 , weight: -27270.0
# =================================
# in 26060 epoch, average loss: -71786790.4
#                 , loss1: 2630.297265625
#                 , loss2: 13754.684375
#                 , weight: -27320.0
# =================================
# in 26070 epoch, average loss: -71968518.4
#                 , loss1: 2631.9583984375
#                 , loss2: 8980.13125
#                 , weight: -27370.0
# =================================
# in 26080 epoch, average loss: -71782060.8
#                 , loss1: 2620.5078125
#                 , loss2: 13085.728125
#                 , weight: -27420.0
# =================================
# in 26090 epoch, average loss: -71699296.0
#                 , loss1: 2612.828125
#                 , loss2: 16482.759375
#                 , weight: -27470.0
# =================================
# in 26100 epoch, average loss: -72232454.4
#                 , loss1: 2627.5984375
#                 , loss2: 19959.4390625
#                 , weight: -27520.0
# =================================
# in 26110 epoch, average loss: -72341625.6
#                 , loss1: 2626.3716796875
#                 , loss2: 8303.80078125
#                 , weight: -27570.0
# =================================
# in 26120 epoch, average loss: -72597670.4
#                 , loss1: 2630.99609375
#                 , loss2: 11213.20234375
#                 , weight: -27620.0
# =================================
# in 26130 epoch, average loss: -72436268.8
#                 , loss1: 2620.4716796875
#                 , loss2: 13109.240625
#                 , weight: -27670.0
# =================================
# in 26140 epoch, average loss: -71370489.6
#                 , loss1: 2577.6123046875
#                 , loss2: 22731.390625
#                 , weight: -27720.0
# =================================
# in 26150 epoch, average loss: -71501376.0
#                 , loss1: 2578.215625
#                 , loss2: 37955.5
#                 , weight: -27770.0
# =================================
# in 26160 epoch, average loss: -72778099.2
#                 , loss1: 2619.2896484375
#                 , loss2: 31671.490625
#                 , weight: -27820.0
# =================================
# in 26170 epoch, average loss: -71953593.6
#                 , loss1: 2585.062890625
#                 , loss2: 33260.98125
#                 , weight: -27870.0
# =================================
# in 26180 epoch, average loss: -69815219.2
#                 , loss1: 2505.9484375
#                 , loss2: 94536.175
#                 , weight: -27920.0
# =================================
# in 26190 epoch, average loss: -70488352.0
#                 , loss1: 2526.5572265625
#                 , loss2: 122728.375
#                 , weight: -27970.0
# =================================
# in 26200 epoch, average loss: -70874918.4
#                 , loss1: 2536.3150390625
#                 , loss2: 135560.0375
#                 , weight: -28020.0
# =================================
# in 26210 epoch, average loss: -71129900.8
#                 , loss1: 2538.507421875
#                 , loss2: 68923.1625
#                 , weight: -28070.0
# =================================
# in 26220 epoch, average loss: -71434105.6
#                 , loss1: 2543.764453125
#                 , loss2: 39350.4125
#                 , weight: -28120.0
# =================================
# in 26230 epoch, average loss: -71740230.4
#                 , loss1: 2549.687890625
#                 , loss2: 27115.846875
#                 , weight: -28170.0
# =================================
# in 26240 epoch, average loss: -72045798.4
#                 , loss1: 2555.5869140625
#                 , loss2: 15391.675
#                 , weight: -28220.0
# =================================
# in 26250 epoch, average loss: -72230323.2
#                 , loss1: 2557.4365234375
#                 , loss2: 10861.96015625
#                 , weight: -28270.0
# =================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 11
#       9 elif hgnn_trainer.weight < limit:
#      10     hgnn_trainer.weight = limit
# ---> 11 loss,loss_1,loss_2 = hgnn_trainer.run(epoch=epoch)
#      12 temp_loss_total += loss
#      13 temp_loss1 += loss_1
#
# Cell In[56], line 32, in Trainer.run(self, epoch)
#      30 outs = self.forward(self.X)
#      31 loss, loss_1, loss_2 = loss_bs_matrix(outs, self.hg, device=DEVICE,weight=self.weight)
# ---> 32 loss.backward()
#      33 self.optimizer.step()
#      35 return loss.item(), loss_1.item(), loss_2.item()
#
# File ~/.conda/envs/partition/lib/python3.10/site-packages/torch/_tensor.py:488, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     478 if has_torch_function_unary(self):
#     479     return handle_torch_function(
#     480         Tensor.backward,
#     481         (self,),
#    (...)
#     486         inputs=inputs,
#     487     )
# --> 488 torch.autograd.backward(
#     489     self, gradient, retain_graph, create_graph, inputs=inputs
#     490 )
#
# File ~/.conda/envs/partition/lib/python3.10/site-packages/torch/autograd/__init__.py:197, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     192     retain_graph = create_graph
#     194 # The reason we repeat same the comment below is that
#     195 # some Python versions print out the first line of a multi-line function
#     196 # calls in the traceback and some print out the last line
# --> 197 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     198     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     199     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
hgnn_trainer.eval()
outs = hgnn_trainer.forward(hgnn_trainer.X)
outs_straight = StraightThroughEstimator.apply(outs)
G_clone = G.clone()
edges, _  = G_clone.e
cut = 0
for vertices in edges:
    if torch.prod(outs_straight[list(vertices)], dim=0).sum() == 0:
        cut += 1
    else:
        G_clone.remove_hyperedges(vertices)
assert cut == G_clone.num_e
cut
# Out:
# 1305

# %%
num_nodes = outs_straight.sum(dim=0)
print(num_nodes)
# Out:
# tensor([2468., 2468., 2467.], device='cuda:1', grad_fn=<SumBackward1>)
